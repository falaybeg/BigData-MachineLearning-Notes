# %% [markdown]
# # Low Level API: Distributed Shared Variables
# Lookup table is an array or matrix of data that contains items that are searched. Broadcast Variable is commonly used as a lookup table.

# %%
import findspark 
findspark.init()

# %%
from pyspark.sql import SparkSession

# %%
pyspark = SparkSession.builder \
.master("local[4]")\
.appName("PairRDD")\
.config("spark.executer.memory","2g")\
.config("spark.driver.memory","2g")\
.getOrCreate()

# %% [markdown]
# ## ---> Reading products

# %%
def read_product():
    products_text_wrapper = open("data/retail_db/products.csv", "r", encoding="utf-8")
    products = products_text_wrapper.readlines()
    product_id_name = {}
    
    for line in products:
        if "productCategoryId" not in line:
            product_id = int(line.split(",")[0])
            product_category = int(line.split(",")[1])
            product_name = line.split(",")[2]
            product_id_name.update({product_id: (product_name, product_category)})
            
    return product_id_name

# %%
products = read_product()

# %%
broadcast_products = sc.broadcast(products)

# %%
broadcast_products.value
# Out:
# {1: ('Quest Q64 10 FT. x 10 FT. Slant Leg Instant U', 2),
#  2: ("Under Armour Men's Highlight MC Football Clea", 2),
#  3: ("Under Armour Men's Renegade D Mid Football Cl", 2),
#  4: ("Under Armour Men's Renegade D Mid Football Cl", 2),
#  5: ('Riddell Youth Revolution Speed Custom Footbal', 2),
#  6: ("Jordan Men's VI Retro TD Football Cleat", 2),
#  7: ('Schutt Youth Recruit Hybrid Custom Football H', 2),
#  8: ("Nike Men's Vapor Carbon Elite TD Football Cle", 2),
#  9: ('Nike Adult Vapor Jet 3.0 Receiver Gloves', 2),
#  10: ("Under Armour Men's Highlight MC Football Clea", 2),
#  11: ('Fitness Gear 300 lb Olympic Weight Set', 2),
#  12: ("Under Armour Men's Highlight MC Alter Ego Fla", 2),
#  13: ("Under Armour Men's Renegade D Mid Football Cl", 2),
#  14: ('Quik Shade Summit SX170 10 FT. x 10 FT. Canop', 2),
#  15: ("Under Armour Kids' Highlight RM Alter Ego Sup", 2),
#  16: ('Riddell Youth 360 Custom Football Helmet', 2),
#  17: ("Under Armour Men's Highlight MC Football Clea", 2),
#  18: ("Reebok Men's Full Zip Training Jacket", 2),
#  19: ("Nike Men's Fingertrap Max Training Shoe", 2),
#  20: ("Under Armour Men's Highlight MC Football Clea", 2),
#  21: ("Under Armour Kids' Highlight RM Football Clea", 2),
#  22: ('Kijaro Dual Lock Chair', 2),
#  23: ("Under Armour Men's Highlight MC Alter Ego Hul", 2),
#  24: ('Elevation Training Mask 2.0', 2),
#  25: ('Quest Q64 10 FT. x 10 FT. Slant Leg Instant U', 3),
#  26: ("Nike Men's USA White Home Stadium Soccer Jers", 3),
#  27: ('Nike Youth USA Away Stadium Replica Soccer Je', 3),
#  28: ('adidas Brazuca 2014 Top Glider Soccer Ball', 3),
#  29: ("Nike Men's USA Away Stadium Replica Soccer Je", 3),
#  30: ("adidas Men's Germany Home Soccer Jersey", 3),
#  31: ('Nike+ Fuelband SE', 3),
#  32: ("PUMA Men's evoPOWER 1 Tricks FG Soccer Cleat", 3),
#  33: ('adidas Brazuca 2014 Top Repliqué Soccer Ball', 3),
#  34: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 3),
#  35: ('adidas Brazuca 2014 Official Match Ball', 3),
#  36: ("adidas Men's Germany Black/Red Away Match Soc", 3),
#  37: ("adidas Kids' F5 Messi FG Soccer Cleat", 3),
#  38: ("Nike Men's Hypervenom Phantom Premium FG Socc", 3),
#  39: ("Nike Women's Pro Victory Compression Bra", 3),
#  40: ('Quik Shade Summit SX170 10 FT. x 10 FT. Canop', 3),
#  41: ("adidas Men's Mexico Home Soccer Jersey", 3),
#  42: ("adidas Kids' F10 Messi TRX FG Soccer Cleat", 3),
#  43: ('Kijaro Dual Lock Chair', 3),
#  44: ("adidas Men's F10 Messi TRX FG Soccer Cleat", 3),
#  45: ("adidas Men's F10 Messi FG Soccer Cleat", 3),
#  46: ("Quest 12' x 12' Dome Canopy", 3),
#  47: ("Nike Women's Pro Hyperwarm Fitted Tights", 3),
#  48: ('adidas Brazuca Final Rio Official Match Ball', 3),
#  49: ('Diamondback Adult Sorrento Mountain Bike 2014', 4),
#  50: ('Quest Q64 10 FT. x 10 FT. Slant Leg Instant U', 4),
#  51: ('MAC Sports Collapsible Wagon', 4),
#  52: ('Easton Mako Youth Bat 2014 (-11)', 4),
#  53: ('adidas Brazuca 2014 Top Glider Soccer Ball', 4),
#  54: ('Nike+ Fuelband SE', 4),
#  55: ('adidas Brazuca 2014 Top Repliqué Soccer Ball', 4),
#  56: ('Fitbit Flex Wireless Activity & Sleep Wristba', 4),
#  57: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 4),
#  58: ("Diamondback Boys' Insight 24 Performance Hybr", 4),
#  59: ('adidas Brazuca 2014 Official Match Ball', 4),
#  60: ('SOLE E25 Elliptical', 4),
#  61: ("Diamondback Girls' Clarity 24 Hybrid Bike 201", 4),
#  62: ('Easton XL1 Youth Bat 2014 (-10)', 4),
#  63: ('Fitness Gear 300 lb Olympic Weight Set', 4),
#  64: ("Nike Women's Pro Victory Compression Bra", 4),
#  65: ('Quik Shade Summit SX170 10 FT. x 10 FT. Canop', 4),
#  66: ('SOLE F85 Treadmill', 4),
#  67: ('Kijaro Dual Lock Chair', 4),
#  68: ('Diamondback Adult Outlook Mountain Bike 2014', 4),
#  69: ('Easton S1 Youth Bat 2014 (-12)', 4),
#  70: ('Elevation Training Mask 2.0', 4),
#  71: ('Diamondback Adult Response XE Mountain Bike 2', 4),
#  72: ("Quest 12' x 12' Dome Canopy", 4),
#  73: ('Quest Q64 10 FT. x 10 FT. Slant Leg Instant U', 5),
#  74: ('"Goaliath 54"" In-Ground Basketball Hoop with P"', 5),
#  75: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 5),
#  76: ("Jordan Men's VI Retro TD Football Cleat", 5),
#  77: ('Schutt Youth Recruit Hybrid Custom Football H', 5),
#  78: ("Nike Kids' Grade School KD VI Basketball Shoe", 5),
#  79: ('Fitness Gear 300 lb Olympic Weight Set', 5),
#  80: ("Nike Women's Pro Victory Compression Bra", 5),
#  81: ('Quik Shade Summit SX170 10 FT. x 10 FT. Canop', 5),
#  82: ('Kijaro Dual Lock Chair', 5),
#  83: ('Elevation Training Mask 2.0', 5),
#  84: ("Nike Men's KD VI Basketball Shoe", 5),
#  85: ('"Nike Kids\' Grade School LeBron XI Basketball "', 5),
#  86: ("Quest 12' x 12' Dome Canopy", 5),
#  87: ("Nike Women's Pro Hyperwarm Fitted Tights", 5),
#  88: ("Nike Kids' Grade School KD VI Basketball Shoe", 5),
#  89: ('Nike Elite Crew Basketball Sock', 5),
#  90: ("Nike Men's LeBron XI Basketball Shoe", 5),
#  91: ("Quest Q100 10' X 10' Dome Canopy", 5),
#  92: ("Nike Men's LeBron XI Low Basketball Shoe", 5),
#  93: ("Under Armour Men's Tech II T-Shirt", 5),
#  94: ('Fitness Gear Pro Utility Bench', 5),
#  95: ('Nike Hoops Elite Team Backpack', 5),
#  96: ('Teeter Hang Ups NXT-S Inversion Table', 5),
#  97: ('Quest Q64 10 FT. x 10 FT. Slant Leg Instant U', 6),
#  98: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 6),
#  99: ("Nike Women's Pro Victory Compression Bra", 6),
#  100: ('Quik Shade Summit SX170 10 FT. x 10 FT. Canop', 6),
#  101: ('Kijaro Dual Lock Chair', 6),
#  102: ("Quest 12' x 12' Dome Canopy", 6),
#  103: ("Nike Women's Pro Hyperwarm Fitted Tights", 6),
#  104: ('Nike Elite Crew Basketball Sock', 6),
#  105: ("Quest Q100 10' X 10' Dome Canopy", 6),
#  106: ('Teeter Hang Ups NXT-S Inversion Table', 6),
#  107: ('SKLZ Sport-Brella XL', 6),
#  108: ("E-Z Up Vista 12' x 12' Recreational Instant S", 6),
#  109: ("Under Armour Men's Ignite Camo II Slide", 6),
#  110: ('McDavid HEX Extended Leg Sleeves', 6),
#  111: ('Kijaro XXL Dual Lock Oversized Chair', 6),
#  112: ("Nike Women's Pro Hyperwarm Half Zip Long Slee", 6),
#  113: ("Nike Men's Alpha Pro D Mid Football Cleat", 6),
#  114: ("Nike Men's Fly Shorts 2.0", 6),
#  115: ("Under Armour Men's Highlight RM Football Clea", 6),
#  116: ("Nike Men's Comfort 2 Slide", 6),
#  117: ('YETI Tundra 65 Chest Cooler', 6),
#  118: ("Quest 12' x 12' Screen House", 6),
#  119: ('Quest Oversized Arm Chair', 6),
#  120: ('Nike Hyper Elite Crew Basketball Sock', 6),
#  121: ('Quest Q64 10 FT. x 10 FT. Slant Leg Instant U', 7),
#  122: ('Nike+ Fuelband SE', 7),
#  123: ('Fitbit Flex Wireless Activity & Sleep Wristba', 7),
#  124: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 7),
#  125: ("Nike Women's Pro Victory Compression Bra", 7),
#  126: ('Quik Shade Summit SX170 10 FT. x 10 FT. Canop', 7),
#  127: ('Stiga Master Series ST3100 Competition Indoor', 7),
#  128: ('Kijaro Dual Lock Chair', 7),
#  129: ("Quest 12' x 12' Dome Canopy", 7),
#  130: ("Nike Women's Pro Hyperwarm Fitted Tights", 7),
#  131: ('Nike Elite Crew Basketball Sock', 7),
#  132: ('Under Armour Hustle Backpack', 7),
#  133: ("Quest Q100 10' X 10' Dome Canopy", 7),
#  134: ("Nike Women's Legend V-Neck T-Shirt", 7),
#  135: ('Nike Dri-FIT Crew Sock 6 Pack', 7),
#  136: ('Nike Hoops Elite Team Backpack', 7),
#  137: ('Teeter Hang Ups NXT-S Inversion Table', 7),
#  138: ('SKLZ Sport-Brella XL', 7),
#  139: ("E-Z Up Vista 12' x 12' Recreational Instant S", 7),
#  140: ("Under Armour Men's Ignite Camo II Slide", 7),
#  141: ("Under Armour Boys' Match Play Golf Polo", 7),
#  142: ('McDavid HEX Extended Leg Sleeves', 7),
#  143: ('Kijaro XXL Dual Lock Oversized Chair', 7),
#  144: ('Garmin Forerunner 220 GPS Watch', 7),
#  145: ('Quest Q64 10 FT. x 10 FT. Slant Leg Instant U', 8),
#  146: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 8),
#  147: ("Nike Women's Pro Victory Compression Bra", 8),
#  148: ('Quik Shade Summit SX170 10 FT. x 10 FT. Canop', 8),
#  149: ('Kijaro Dual Lock Chair', 8),
#  150: ("Quest 12' x 12' Dome Canopy", 8),
#  151: ("Nike Women's Pro Hyperwarm Fitted Tights", 8),
#  152: ("Quest Q100 10' X 10' Dome Canopy", 8),
#  153: ('Teeter Hang Ups NXT-S Inversion Table', 8),
#  154: ('SKLZ Sport-Brella XL', 8),
#  155: ("E-Z Up Vista 12' x 12' Recreational Instant S", 8),
#  156: ("Under Armour Men's Ignite Camo II Slide", 8),
#  157: ("Reebok Women's Performance Essentials Printed", 8),
#  158: ('McDavid HEX Extended Leg Sleeves', 8),
#  159: ('Kijaro XXL Dual Lock Oversized Chair', 8),
#  160: ("Nike Women's Pro Hyperwarm Half Zip Long Slee", 8),
#  161: ("Nike Men's Comfort 2 Slide", 8),
#  162: ('YETI Tundra 65 Chest Cooler', 8),
#  163: ("Quest 12' x 12' Screen House", 8),
#  164: ("adidas Women's Tiro 13 Soccer Pants", 8),
#  165: ('Quest Oversized Arm Chair', 8),
#  166: ("Under Armour Men's Ignite III Slide", 8),
#  167: ("Nike Women's Pro Printed Sports Bra", 8),
#  168: ('"Nike Women\'s 3"" Pro Compression Shorts"', 8),
#  169: ('Diamondback Adult Sorrento Mountain Bike 2014', 9),
#  170: ('Quest Q64 10 FT. x 10 FT. Slant Leg Instant U', 9),
#  171: ('MAC Sports Collapsible Wagon', 9),
#  172: ("Nike Women's Tempo Shorts", 9),
#  173: ("Under Armour Men's Highlight MC Football Clea", 9),
#  174: ("Nike Men's USA White Home Stadium Soccer Jers", 9),
#  175: ("Nike Women's Tempo Shorts", 9),
#  176: ('Easton Mako Youth Bat 2014 (-11)', 9),
#  177: ('Nike Youth USA Away Stadium Replica Soccer Je', 9),
#  178: ('adidas Brazuca 2014 Top Glider Soccer Ball', 9),
#  179: ("Brooks Women's Adrenaline GTS 13 Running Shoe", 9),
#  180: ("Nike Men's USA Away Stadium Replica Soccer Je", 9),
#  181: ('Lifetime Freestyle XL Stand-Up Paddle Board', 9),
#  182: ("adidas Men's Germany Home Soccer Jersey", 9),
#  183: ('Nike+ Fuelband SE', 9),
#  184: ("PUMA Men's evoPOWER 1 Tricks FG Soccer Cleat", 9),
#  185: ('"Goaliath 54"" In-Ground Basketball Hoop with P"', 9),
#  186: ('adidas Brazuca 2014 Top Repliqué Soccer Ball', 9),
#  187: ('"Top Flite Women\'s XL 12-Piece Complete Set - "', 9),
#  188: ('Fitbit Flex Wireless Activity & Sleep Wristba', 9),
#  189: ("Nike Women's Tempo Shorts", 9),
#  190: ("Under Armour Men's Renegade D Mid Football Cl", 9),
#  191: ("Nike Men's Free 5.0+ Running Shoe", 9),
#  192: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 9),
#  193: ('Diamondback Adult Sorrento Mountain Bike 2014', 10),
#  194: ('Nike+ Fuelband SE', 10),
#  195: ('Fitbit Flex Wireless Activity & Sleep Wristba', 10),
#  196: ("Diamondback Boys' Insight 24 Performance Hybr", 10),
#  197: ('SOLE E25 Elliptical', 10),
#  198: ("Diamondback Girls' Clarity 24 Hybrid Bike 201", 10),
#  199: ('SOLE F85 Treadmill', 10),
#  200: ('Diamondback Adult Outlook Mountain Bike 2014', 10),
#  201: ('Elevation Training Mask 2.0', 10),
#  202: ('Diamondback Adult Response XE Mountain Bike 2', 10),
#  203: ('GoPro HERO3+ Black Edition Camera', 10),
#  204: ("Rollerblade Men's Spark 84 Inline Skate", 10),
#  205: ('Diamondback Adult Wildwood Citi Classic Comfo', 10),
#  206: ('Diamondback Adult Edgewood Hybrid Bike 2014', 10),
#  207: ("Rollerblade Women's Spark 84 Inline Skates", 10),
#  208: ('SOLE E35 Elliptical', 10),
#  209: ('Quest 15 FT Trampoline Enclosure Combo', 10),
#  210: ('Thule Trailway 4-Bike Hitch Vehicle Rack', 10),
#  211: ('Diamondback Grind BMX Bike 2014', 10),
#  212: ("Under Armour Men's Ignite Camo II Slide", 10),
#  213: ('Exerpeutic 900XL Magnetic Recumbent Bike with', 10),
#  214: ("Diamondback Women's Vital 2 Hybrid Bike 2014", 10),
#  215: ('Garmin vivofit Fitness Band with HRM', 10),
#  216: ('Yakima DoubleDown Ace Hitch Mount 4-Bike Rack', 10),
#  217: ('Fitness Gear 300 lb Olympic Weight Set', 11),
#  218: ('Elevation Training Mask 2.0', 11),
#  219: ('Fitness Gear Pro Utility Bench', 11),
#  220: ('Teeter Hang Ups NXT-S Inversion Table', 11),
#  221: ('Fitness Gear Pro Olympic Bench', 11),
#  222: ('Fitness Gear Pro Half Rack', 11),
#  223: ('Teeter Hang-Ups EP-970 Limited Inversion Tabl', 11),
#  224: ('"PowerBlock Classic 50 lb Adjustable Dumbbell "', 11),
#  225: ('Marcy Pro Circuit Trainer', 11),
#  226: ('Bowflex SelectTech 1090 Dumbbells', 11),
#  227: ("Reebok Men's CrossFit Nano 3.0 Training Shoe", 11),
#  228: ('Fitness Gear Olympic Bench', 11),
#  229: ('Marcy Diamond 9010 Smith Cage', 11),
#  230: ('BOSU Balance Trainer', 11),
#  231: ("Nike Men's Romaleos 2 Weightlifting Shoe", 11),
#  232: ("adidas Men's Powerlift 2 Training Shoe", 11),
#  233: ('Core Fitness 5 - 50 lb Adjustable Dumbbells -', 11),
#  234: ('Fitness Gear Pro Core Bench', 11),
#  235: ('Under Armour Hustle Storm Medium Duffle Bag', 11),
#  236: ('PowerBlock 24 lb Adjustable Dumbbell Set', 11),
#  237: ("Fitness Gear 7' Olympic Bar", 11),
#  238: ('Fitness Gear Heavy Bag Stand', 11),
#  239: ("Reebok Women's CrossFit Nano 2.0 Training Sho", 11),
#  240: ('Stamina Air Rower', 11),
#  241: ("Nike Women's Tempo Shorts", 12),
#  242: ("Nike Women's Tempo Shorts", 12),
#  243: ("Brooks Women's Adrenaline GTS 13 Running Shoe", 12),
#  244: ('Nike+ Fuelband SE', 12),
#  245: ('Fitbit Flex Wireless Activity & Sleep Wristba', 12),
#  246: ("Nike Women's Tempo Shorts", 12),
#  247: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 12),
#  248: ("Nike Women's Free 4.0 Running Shoe", 12),
#  249: ("Under Armour Women's Micro G Skulpt Running S", 12),
#  250: ("Under Armour Women's Play Up Shorts", 12),
#  251: ("Brooks Women's Ghost 6 Running Shoe", 12),
#  252: ("Nike Women's Pro Victory Compression Bra", 12),
#  253: ("Nike Women's Free 5.0+ Running Shoe", 12),
#  254: ("Brooks Women's Ghost 6 Running Shoe", 12),
#  255: ("ASICS Women's GEL-Noosa Tri 9 Running Shoe", 12),
#  256: ('Elevation Training Mask 2.0', 12),
#  257: ("Under Armour Women's Tech T-Shirt", 12),
#  258: ("Nike Women's Free 5.0 TR FIT PRT 4 Training S", 12),
#  259: ("Nike Women's Pro Hyperwarm Fitted Tights", 12),
#  260: ("ASICS Women's GEL-Nimbus 15 Running Shoe", 12),
#  261: ("ASICS Women's GEL-Cumulus 15 Running Shoe", 12),
#  262: ('Fitness Gear Pro Utility Bench', 12),
#  263: ("Nike Women's Legend V-Neck T-Shirt", 12),
#  264: ('Nike Dri-FIT Crew Sock 6 Pack', 12),
#  265: ('Elevation Training Mask 2.0', 13),
#  266: ("Under Armour Men's Ignite Camo II Slide", 13),
#  267: ("Nike Men's Comfort 2 Slide", 13),
#  268: ('Everlast PowerCore 2 Station Stand and Bag Ki', 13),
#  269: ("Under Armour Men's Ignite III Slide", 13),
#  270: ("Nike Men's Comfort 2 Slide", 13),
#  271: ("Under Armour Kids' Ignite III Slide", 13),
#  272: ("Under Armour Women's Ignite VI Slide", 13),
#  273: ("Under Armour Kids' Mercenary Slide", 13),
#  274: ("Nike Men's Benassi Swoosh Slide", 13),
#  275: ("Under Armour Girls' UA Ignite VI Slide", 13),
#  276: ("Under Armour Women's Ignite Slide", 13),
#  277: ("Under Armour Women's Ignite VI Camo Slide", 13),
#  278: ("Under Armour Men's Compression EV SL Slide", 13),
#  279: ("Nike Men's Air LeBron 3 Elite Slide", 13),
#  280: ('Under Armour Hustle Storm Medium Duffle Bag', 13),
#  281: ('Fitness Gear Heavy Bag Stand', 13),
#  282: ("Under Armour Women's Ignite PIP VI Slide", 13),
#  283: ("Under Armour Kids' Mercenary Slide", 13),
#  284: ("Under Armour Women's Ignite VI Slide", 13),
#  285: ("Under Armour Men's Mercenary Slide", 13),
#  286: ("Under Armour Men's Ignite III Slide", 13),
#  287: ("Nike Men's Comfort 2 Slide", 13),
#  288: ("Nike Men's Air LeBron 3 Elite Slide", 13),
#  289: ('Nike+ Fuelband SE', 38),
#  290: ('Fitbit Flex Wireless Activity & Sleep Wristba', 38),
#  291: ('Garmin Forerunner 220 GPS Watch', 38),
#  292: ("Garmin Women's Forerunner 10 GPS Watch", 38),
#  293: ('Garmin vivofit Fitness Band with HRM', 38),
#  294: ('Garmin Forerunner 10 GPS Watch', 38),
#  295: ('Fitbit The One Wireless Activity & Sleep Trac', 38),
#  296: ('Nike+ Sportwatch GPS Powered by TomTom with S', 38),
#  297: ('Garmin vivofit Fitness Band', 38),
#  298: ('Garmin Forerunner 15 GPS Watch with HRM', 38),
#  299: ('Jawbone UP24 Activity Tracker', 38),
#  300: ('Garmin Forerunner 620 GPS Watch with Heart Ra', 38),
#  301: ('Garmin Forerunner 15 GPS Watch', 38),
#  302: ('Nike+ Sportwatch GPS Powered by TomTom', 38),
#  303: ('Garmin Forerunner 910XT GPS Watch', 38),
#  304: ('"Garmin Forerunner 220 GPS Watch with Premium "', 38),
#  305: ('Mio ALPHA Heart Rate Monitor/Sport Watch', 38),
#  306: ('Polar FT4 Heart Rate Monitor', 38),
#  307: ('Garmin Forerunner 910XT with HRM', 38),
#  308: ('Fitbit Zip Wireless Activity Tracker', 38),
#  309: ('Fitbit Aria Wi-Fi Smart Scale', 38),
#  310: ('Beats by Dr. Dre Solo2 Headphones', 38),
#  311: ('Polar Loop Activity Tracker', 38),
#  312: ('TomTom Multi-Sport Cardio + Cycle GPS Watch w', 38),
#  313: ("Under Armour Women's Seamless Essential Sport", 15),
#  314: ("Nike Women's Studio Wrap", 15),
#  315: ("Nike Women's Legend Tight Capris 2.0", 15),
#  316: ("Nike Women's Legend Regular Capris 2.0", 15),
#  317: ("Nike Women's Printed Studio Wrap", 15),
#  318: ("Under Armour Women's Seamless Advantage Sport", 15),
#  319: ("Under Armour Women's HeatGear Sonic Printed C", 15),
#  320: ('Manduka PRO Yoga Mat', 15),
#  321: ("Reebok Women's Fitness Essentials Regular Fit", 15),
#  322: ("Nike Women's Studio Wrap Three-Part Pack", 15),
#  323: ("Under Armour Women's Achieve T-Back Tank Top", 15),
#  324: ("Reebok Women's Fitness Essential Slim Fit Cap", 15),
#  325: ("lucy Women's Hatha Capri Leggings", 15),
#  326: ('Mission Enduracool Instant Cooling Towel', 15),
#  327: ("Reebok Women's Performance Regular Motion Fit", 15),
#  328: ("Under Armour Women's Perfect Flowy Tank Top", 15),
#  329: ("Under Armour Women's Essential Banded Tank To", 15),
#  330: ("Nike Women's Dri-FIT Cotton Tight Capris", 15),
#  331: ("The North Face Women's Be Calm Tank Top", 15),
#  332: ("Under Armour Women's Pure Stretch Sheer Cheek", 15),
#  333: ("lucy Women's Heart Center Tank Top", 15),
#  334: ("Reebok Women's Fitness Essentials Regular Fit", 15),
#  335: ("Nike Women's Dri-FIT Cotton Regular-Fit Capri", 15),
#  336: ('"Nike Swoosh Headband - 2"""', 15),
#  337: ('Fitness Gear 300 lb Olympic Weight Set', 16),
#  338: ("Nike Men's Fingertrap Max Training Shoe", 16),
#  339: ('Elevation Training Mask 2.0', 16),
#  340: ("PRIMED 12' x 6' Instant Soccer Goal", 16),
#  341: ('Fitness Gear Pro Utility Bench', 16),
#  342: ("SKLZ Quickster 12' x 6' Portable Soccer Goal", 16),
#  343: ('Teeter Hang Ups NXT-S Inversion Table', 16),
#  344: ("Under Armour Men's Ignite Camo II Slide", 16),
#  345: ('Fitness Gear Pro Olympic Bench', 16),
#  346: ('Fitness Gear Pro Half Rack', 16),
#  347: ('adidas Brazuca Final Rio Top Glider Soccer Ba', 16),
#  348: ('McDavid HEX Extended Leg Sleeves', 16),
#  349: ("Franklin 12' x 6' Competition Steel Soccer Go", 16),
#  350: ("Nike Men's Comfort 2 Slide", 16),
#  351: ('Jugs Complete Practice Travel Screen', 16),
#  352: ("Under Armour Men's Ignite III Slide", 16),
#  353: ("Nike Men's Comfort 2 Slide", 16),
#  354: ("Nike Men's Fingertrap Max Training Shoe", 16),
#  355: ("Nike Men's Free Trainer 5.0 Training Shoe", 16),
#  356: ("PRIMED 7' x 5' Soccer Trainer", 16),
#  357: ("Under Armour Kids' Ignite III Slide", 16),
#  358: ("Reebok Women's Solid Classic Tank Swimsuit", 16),
#  359: ("Nike Men's Free TR 5.0 TB Training Shoe", 16),
#  360: ("Under Armour Women's Ignite VI Slide", 16),
#  361: ('Bowflex Uppercut', 17),
#  362: ('Perfect Fitness Perfect Ab Strap Pro', 17),
#  363: ('Total Gym 1100', 17),
#  364: ('Total Gym 1400', 17),
#  365: ('Perfect Fitness Perfect Rip Deck', 17),
#  366: ('Gazelle Supreme Glider', 17),
#  367: ('Gazelle Edge Pro Glider', 17),
#  368: ('Pink BOSU Balance Trainer', 17),
#  369: ('BOSU Ballast Ball', 17),
#  370: ('Kettleglove Unisex Kettleball Gloves', 17),
#  371: ('Total Gym 1900', 17),
#  372: ('Perfect Ab Carver Pro', 17),
#  373: ('Perfect Fitness Multi Gym Pro', 17),
#  374: ('Perfect Pushup BASIC', 17),
#  375: ("Gold's Gym K10 7-in-1 Body Building Kit", 17),
#  376: ('Perfect Pushup V2 Performance', 17),
#  377: ('Perfect Pullup Basic', 17),
#  378: ('AB Roller Evolution', 17),
#  379: ('Perfect Multi-Gym - As Seen on TV!', 17),
#  380: ('BOSU Balance Trainer', 17),
#  381: ("Under Armour Men's Highlight MC Football Clea", 18),
#  382: ("PUMA Men's evoPOWER 1 Tricks FG Soccer Cleat", 18),
#  383: ("Under Armour Men's Renegade D Mid Football Cl", 18),
#  384: ("Under Armour Men's Renegade D Mid Football Cl", 18),
#  385: ("Jordan Men's VI Retro TD Football Cleat", 18),
#  386: ("Nike Men's Vapor Carbon Elite TD Football Cle", 18),
#  387: ("adidas Kids' F5 Messi FG Soccer Cleat", 18),
#  388: ("Nike Men's Hypervenom Phantom Premium FG Socc", 18),
#  389: ("Under Armour Men's Highlight MC Football Clea", 18),
#  390: ("Under Armour Men's Highlight MC Alter Ego Fla", 18),
#  391: ("Under Armour Men's Renegade D Mid Football Cl", 18),
#  392: ("Under Armour Kids' Highlight RM Alter Ego Sup", 18),
#  393: ("Under Armour Men's Highlight MC Football Clea", 18),
#  394: ("Nike Men's Fingertrap Max Training Shoe", 18),
#  395: ("adidas Kids' F10 Messi TRX FG Soccer Cleat", 18),
#  396: ("Under Armour Men's Highlight MC Football Clea", 18),
#  397: ("Under Armour Kids' Highlight RM Football Clea", 18),
#  398: ("adidas Men's F10 Messi TRX FG Soccer Cleat", 18),
#  399: ("Under Armour Men's Highlight MC Alter Ego Hul", 18),
#  400: ("Under Armour Men's Highlight MC Football Clea", 18),
#  401: ("adidas Men's F10 Messi FG Soccer Cleat", 18),
#  402: ("Under Armour Men's Highlight MC Alter Ego Cap", 18),
#  403: ("Nike Men's CJ Elite 2 TD Football Cleat", 18),
#  404: ("Nike Men's Vapor Carbon Elite TD Football Cle", 18),
#  405: ("Under Armour Men's Highlight MC Football Clea", 19),
#  406: ('Nike+ Fuelband SE', 19),
#  407: ("PUMA Men's evoPOWER 1 Tricks FG Soccer Cleat", 19),
#  408: ('Fitbit Flex Wireless Activity & Sleep Wristba', 19),
#  409: ("Under Armour Men's Renegade D Mid Football Cl", 19),
#  410: ("Nike Men's Free 5.0+ Running Shoe", 19),
#  411: ("Under Armour Men's Renegade D Mid Football Cl", 19),
#  412: ("Jordan Men's VI Retro TD Football Cleat", 19),
#  413: ("Nike Men's Vapor Carbon Elite TD Football Cle", 19),
#  414: ("Nike Men's Hypervenom Phantom Premium FG Socc", 19),
#  415: ("Under Armour Men's Highlight MC Football Clea", 19),
#  416: ("Nike Men's Free 5.0 Running Shoe", 19),
#  417: ("Under Armour Men's Highlight MC Alter Ego Fla", 19),
#  418: ("Under Armour Men's Renegade D Mid Football Cl", 19),
#  419: ("Brooks Men's Adrenaline GTS 13 Running Shoe", 19),
#  420: ("Under Armour Men's Highlight MC Football Clea", 19),
#  421: ("Nike Men's Fingertrap Max Training Shoe", 19),
#  422: ("Under Armour Men's Highlight MC Football Clea", 19),
#  423: ("adidas Men's F10 Messi TRX FG Soccer Cleat", 19),
#  424: ("Under Armour Men's Highlight MC Alter Ego Hul", 19),
#  425: ("Nike Men's Air Max 2014 Running Shoe", 19),
#  426: ("Under Armour Men's Highlight MC Football Clea", 19),
#  427: ("adidas Men's F10 Messi FG Soccer Cleat", 19),
#  428: ("Under Armour Men's Highlight MC Alter Ego Cap", 19),
#  429: ("Brooks Women's Adrenaline GTS 13 Running Shoe", 20),
#  430: ('Nike+ Fuelband SE', 20),
#  431: ('Fitbit Flex Wireless Activity & Sleep Wristba', 20),
#  432: ("Nike Women's Free 4.0 Running Shoe", 20),
#  433: ("Under Armour Women's Micro G Skulpt Running S", 20),
#  434: ("Brooks Women's Ghost 6 Running Shoe", 20),
#  435: ("Nike Women's Free 5.0+ Running Shoe", 20),
#  436: ("Brooks Women's Ghost 6 Running Shoe", 20),
#  437: ("ASICS Women's GEL-Noosa Tri 9 Running Shoe", 20),
#  438: ("Nike Women's Free 5.0 TR FIT PRT 4 Training S", 20),
#  439: ("ASICS Women's GEL-Nimbus 15 Running Shoe", 20),
#  440: ("Nike Men's Mercurial Victory IV FG Soccer Cle", 20),
#  441: ("ASICS Women's GEL-Cumulus 15 Running Shoe", 20),
#  442: ('Nike Dri-FIT Crew Sock 6 Pack', 20),
#  443: ("Nike Women's Air Pegasus+ 30 Running Shoe", 20),
#  444: ("Nike Women's Downshifter 5 Running Shoe", 20),
#  445: ("Nike Women's Air Pegasus+ 30 Running Shoe", 20),
#  446: ("Nike Women's LunarGlide+ 5 Running Shoe", 20),
#  447: ("Nike Women's Free TR Connect 2 Training Shoe", 20),
#  448: ("Nike Women's Zoom Fly Running Shoe", 20),
#  449: ("Mizuno Women's Wave Inspire 9 Running Shoe", 20),
#  450: ('Garmin Forerunner 220 GPS Watch', 20),
#  451: ("Garmin Women's Forerunner 10 GPS Watch", 20),
#  452: ('Garmin vivofit Fitness Band with HRM', 20),
#  453: ("Nike Kids' Grade School KD VI Basketball Shoe", 21),
#  454: ("adidas Kids' F5 Messi FG Soccer Cleat", 21),
#  455: ("Under Armour Kids' Highlight RM Alter Ego Sup", 21),
#  456: ("adidas Kids' F10 Messi TRX FG Soccer Cleat", 21),
#  457: ("Under Armour Kids' Highlight RM Football Clea", 21),
#  458: ('"Nike Kids\' Grade School LeBron XI Basketball "', 21),
#  459: ("Under Armour Kids' Highlight RM Alter Ego Cap", 21),
#  460: ("Under Armour Kids' Highlight RM Alter Ego Bat", 21),
#  461: ("Under Armour Kids' Highlight RM Football Clea", 21),
#  462: ("Under Armour Kids' Highlight RM Alter Ego Fla", 21),
#  463: ("Nike Kids' Grade School KD VI Basketball Shoe", 21),
#  464: ("Nike Kids' Vapor Strike 4 Mid TD Football Cle", 21),
#  465: ("Under Armour Kids' Highlight RM Football Clea", 21),
#  466: ("Under Armour Kids' Highlight RM Alter Ego Hul", 21),
#  467: ("Nike Kids' Vapor Strike 4 Mid TD Football Cle", 21),
#  468: ("Under Armour Kids' C1N MC Football Cleat", 21),
#  469: ("Nike Kids' Vapor Strike 4 Mid TD Football Cle", 21),
#  470: ("adidas Kids' RG III Mid Football Cleat", 21),
#  471: ("Nike Kids' Grade School KD VI Basketball Shoe", 21),
#  472: ("Nike Kids' Vapor Strike 4 Mid TD Football Cle", 21),
#  473: ("Under Armour Kids' Highlight RM Football Clea", 21),
#  474: ('Nike Hyper Elite Crew Basketball Sock', 21),
#  475: ("Nike Kids' Vapor Strike 4 Mid TD Football Cle", 21),
#  476: ('Reebok All Sport Athletic Sock', 21),
#  477: ("Nike Women's Tempo Shorts", 22),
#  478: ("Nike Women's Tempo Shorts", 22),
#  479: ("Brooks Women's Adrenaline GTS 13 Running Shoe", 22),
#  480: ('Nike+ Fuelband SE', 22),
#  481: ('"Top Flite Women\'s XL 12-Piece Complete Set - "', 22),
#  482: ('Fitbit Flex Wireless Activity & Sleep Wristba', 22),
#  483: ("Nike Women's Tempo Shorts", 22),
#  484: ("Nike Men's Free 5.0+ Running Shoe", 22),
#  485: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 22),
#  486: ('Coleman River Gorge 6 Person Dome Tent', 22),
#  487: ("Jordan Men's VI Retro TD Football Cleat", 22),
#  488: ('SOLE E25 Elliptical', 22),
#  489: ("Nike Kids' Grade School KD VI Basketball Shoe", 22),
#  490: ("Nike Women's Free 4.0 Running Shoe", 22),
#  491: ("Under Armour Women's Micro G Skulpt Running S", 22),
#  492: ("Nike Men's Free 5.0 Running Shoe", 22),
#  493: ("Brooks Women's Ghost 6 Running Shoe", 22),
#  494: ("Nike Women's Pro Victory Compression Bra", 22),
#  495: ("Slazenger Women's Ava Sleeveless Fashion Golf", 22),
#  496: ('SOLE F85 Treadmill', 22),
#  497: ("Nike Women's Free 5.0+ Running Shoe", 22),
#  498: ("Brooks Men's Adrenaline GTS 13 Running Shoe", 22),
#  499: ("Brooks Women's Ghost 6 Running Shoe", 22),
#  500: ('Kijaro Dual Lock Chair', 22),
#  501: ("Nike Men's USA White Home Stadium Soccer Jers", 24),
#  502: ("Nike Men's Dri-FIT Victory Golf Polo", 24),
#  503: ('Nike Youth USA Away Stadium Replica Soccer Je', 24),
#  504: ('adidas Brazuca 2014 Top Glider Soccer Ball', 24),
#  505: ("Nike Men's USA Away Stadium Replica Soccer Je", 24),
#  506: ("adidas Men's Germany Home Soccer Jersey", 24),
#  507: ('Nike+ Fuelband SE', 24),
#  508: ("PUMA Men's evoPOWER 1 Tricks FG Soccer Cleat", 24),
#  509: ('adidas Brazuca 2014 Top Repliqué Soccer Ball', 24),
#  510: ('Fitbit Flex Wireless Activity & Sleep Wristba', 24),
#  511: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 24),
#  512: ("Nike Men's Flat Front Tech Golf Shorts", 24),
#  513: ('adidas Brazuca 2014 Official Match Ball', 24),
#  514: ("adidas Men's Germany Black/Red Away Match Soc", 24),
#  515: ("adidas Kids' F5 Messi FG Soccer Cleat", 24),
#  516: ('Callaway X Hot Laser Rangefinder', 24),
#  517: ("Nike Men's Hypervenom Phantom Premium FG Socc", 24),
#  518: ("Nike Women's Pro Victory Compression Bra", 24),
#  519: ("adidas Men's Mexico Home Soccer Jersey", 24),
#  520: ("adidas Men's Ultimate Short Sleeve Shirt", 24),
#  521: ("Nike Men's Dri-FIT Flat Front Tech Golf Pants", 24),
#  522: ("Reebok Men's Full Zip Training Jacket", 24),
#  523: ("adidas Kids' F10 Messi TRX FG Soccer Cleat", 24),
#  524: ("adidas Men's F10 Messi TRX FG Soccer Cleat", 24),
#  525: ("Nike Women's Tempo Shorts", 25),
#  526: ("Nike Men's USA White Home Stadium Soccer Jers", 25),
#  527: ("Nike Women's Tempo Shorts", 25),
#  528: ('Nike Youth USA Away Stadium Replica Soccer Je', 25),
#  529: ('adidas Brazuca 2014 Top Glider Soccer Ball', 25),
#  530: ("Brooks Women's Adrenaline GTS 13 Running Shoe", 25),
#  531: ("Nike Men's USA Away Stadium Replica Soccer Je", 25),
#  532: ("adidas Men's Germany Home Soccer Jersey", 25),
#  533: ('Nike+ Fuelband SE', 25),
#  534: ("PUMA Men's evoPOWER 1 Tricks FG Soccer Cleat", 25),
#  535: ('adidas Brazuca 2014 Top Repliqué Soccer Ball', 25),
#  536: ('"Top Flite Women\'s XL 12-Piece Complete Set - "', 25),
#  537: ('Fitbit Flex Wireless Activity & Sleep Wristba', 25),
#  538: ("Nike Women's Tempo Shorts", 25),
#  539: ('"Nike Women\'s Pro Core 3"" Compression Shorts"', 25),
#  540: ('Coleman River Gorge 6 Person Dome Tent', 25),
#  541: ('adidas Brazuca 2014 Official Match Ball', 25),
#  542: ("adidas Men's Germany Black/Red Away Match Soc", 25),
#  543: ("Lady Hagen Women's Milan Golf Polo", 25),
#  544: ("adidas Kids' F5 Messi FG Soccer Cleat", 25),
#  545: ('Callaway X Hot Laser Rangefinder', 25),
#  546: ("Nike Women's Free 4.0 Running Shoe", 25),
#  547: ("Nike Men's Hypervenom Phantom Premium FG Socc", 25),
#  548: ("Under Armour Women's Micro G Skulpt Running S", 25),
#  549: ("Lotto Men's Zhero Gravity V 700 TF Soccer Cle", 26),
#  550: ("adidas Men's 2014 All-Star Game Tactile Hunte", 26),
#  551: ("Lotto Men's Zhero Gravity V 700 TF Soccer Cle", 26),
#  552: ("Lotto Men's Zhero Gravity V 700 TF Soccer Cle", 26),
#  553: ("adidas Men's 2014 MLS All-Star Game Dueling T", 26),
#  554: ("adidas Men's 2014 MLS All-Star Game Cross Bla", 26),
#  555: ('"adidas Original Men\'s 2014 MLS All-Star Game "', 26),
#  556: ('"adidas Original Men\'s 2014 MLS All-Star Game "', 26),
#  557: ("adidas Men's 2014 MLS All-Star Game Rose City", 26),
#  558: ("adidas Men's 2014 MLS All-Star Game Crest Gre", 26),
#  559: ("adidas Women's 2014 MLS All-Star Game Dueling", 26),
#  560: ("adidas Men's 2014 MLS All-Star Game Replica B", 26),
#  561: ("adidas Men's 2014 MLS All-Star Game Lumber Hu", 26),
#  562: ("adidas Men's 2014 MLS All-Star Game Axis Hunt", 26),
#  563: ("adidas Men's Germany 2014 FIFA World Cup Braz", 26),
#  564: ("Nike Men's Deutschland Weltmeister Winners Bl", 26),
#  565: ('adidas Youth Germany Black/Red Away Match Soc', 26),
#  566: ("adidas Men's Germany Black/Red Away Match Soc", 26),
#  567: ("adidas Men's Germany Black Crest Away Tee", 26),
#  568: ('adidas Youth Germany Black Crest Tee', 26),
#  569: ("adidas Men's Germany Home Soccer Jersey", 26),
#  570: ("adidas Men's Germany Home Replica White Top", 26),
#  571: ("TYR Boys' Venom Blade Splice Jammer", 26),
#  572: ("TYR Boys' Team Digi Jammer", 26),
#  573: ("Lotto Men's Zhero Gravity V 700 TF Soccer Cle", 27),
#  574: ("adidas Men's 2014 All-Star Game Tactile Hunte", 27),
#  575: ("Lotto Men's Zhero Gravity V 700 TF Soccer Cle", 27),
#  576: ("Lotto Men's Zhero Gravity V 700 TF Soccer Cle", 27),
#  577: ("adidas Men's 2014 MLS All-Star Game Dueling T", 27),
#  578: ("adidas Men's 2014 MLS All-Star Game Cross Bla", 27),
#  579: ('"adidas Original Men\'s 2014 MLS All-Star Game "', 27),
#  580: ('"adidas Original Men\'s 2014 MLS All-Star Game "', 27),
#  581: ("adidas Men's 2014 MLS All-Star Game Rose City", 27),
#  582: ("adidas Men's 2014 MLS All-Star Game Crest Gre", 27),
#  583: ("adidas Women's 2014 MLS All-Star Game Dueling", 27),
#  584: ("adidas Men's 2014 MLS All-Star Game Replica B", 27),
#  585: ("adidas Men's 2014 MLS All-Star Game Lumber Hu", 27),
#  586: ("adidas Men's 2014 MLS All-Star Game Axis Hunt", 27),
#  587: ("adidas Men's Germany 2014 FIFA World Cup Braz", 27),
#  588: ("Nike Men's Deutschland Weltmeister Winners Bl", 27),
#  589: ('adidas Youth Germany Black/Red Away Match Soc', 27),
#  590: ("adidas Men's Germany Black/Red Away Match Soc", 27),
#  591: ("adidas Men's Germany Black Crest Away Tee", 27),
#  592: ('adidas Youth Germany Black Crest Tee', 27),
#  593: ("adidas Men's Germany Home Soccer Jersey", 27),
#  594: ("adidas Men's Germany Home Replica White Top", 27),
#  595: ("TYR Girls' Phoenix Maxfit Back Swimsuit", 27),
#  596: ("TYR Girls' Palisade Maxfit Back Swimsuit", 27),
#  597: ('Nike+ Fuelband SE', 41),
#  598: ('Fitbit Flex Wireless Activity & Sleep Wristba', 41),
#  599: ('Callaway X Hot Laser Rangefinder', 41),
#  600: ("Nike Women's Pro Victory Compression Bra", 41),
#  601: ('GoPro HERO3+ Black Edition Camera', 41),
#  602: ('Nike Elite Crew Basketball Sock', 41),
#  603: ('Under Armour Hustle Backpack', 41),
#  604: ('Nike Dri-FIT Crew Sock 6 Pack', 41),
#  605: ('Nike Hoops Elite Team Backpack', 41),
#  606: ('Bushnell 2014 Tour V3 Patriot Pack Laser Rang', 41),
#  607: ('Garmin Approach S3 Golf GPS Watch', 41),
#  608: ('Garmin Forerunner 220 GPS Watch', 41),
#  609: ('Garmin Approach G6 Golf GPS', 41),
#  610: ('GolfBuddy Voice GPS', 41),
#  611: ("Garmin Women's Forerunner 10 GPS Watch", 41),
#  612: ('Garmin vivofit Fitness Band with HRM', 41),
#  613: ('Garmin Forerunner 10 GPS Watch', 41),
#  614: ('Fitbit The One Wireless Activity & Sleep Trac', 41),
#  615: ('Primos Truth Cam Supercharged Blackout 7 MP G', 41),
#  616: ('Nike+ Sportwatch GPS Powered by TomTom with S', 41),
#  617: ('Nike Hyper Elite Crew Basketball Sock', 41),
#  618: ("Nike Women's Pro Printed Sports Bra", 41),
#  619: ('Nike Vapor Crew Football Sock', 41),
#  620: ("Nike Women's Pro Padded Sports Bra", 41),
#  621: ("Under Armour Men's Performance Chino Straight", 29),
#  622: ("Nike Kids' Toddler Air KD VII Basketball Shoe", 29),
#  623: ("adidas Men's Energy Boost Icon Metal Baseball", 29),
#  624: ('adidas Batting Helmet Hardware Kit', 29),
#  625: ("Nike Men's Kobe IX Elite Low Basketball Shoe", 29),
#  626: ("Nike Men's KD VII Basketball Shoe", 29),
#  627: ("Under Armour Girls' Toddler Spine Surge Runni", 29),
#  628: ('"Under Armour Elevate 22 oz. Leak-Proof Water "', 29),
#  629: ("Nike Men's LeBron XI Low Basketball Shoe", 29),
#  630: ("ASICS Men's GEL-Blast 6 Volleyball Shoe", 29),
#  631: ('Nike Lunarwaverly Golf Shoes', 29),
#  632: ('Nike Lunarwaverly Golf Shoes', 29),
#  633: ('Nike Lunarwaverly Golf Shoes', 29),
#  634: ('Nike Lunarwaverly Golf Shoes', 29),
#  635: ('Nike Lunar Mount Royal Golf Shoes', 29),
#  636: ('Nike Lunar Mount Royal Golf Shoes', 29),
#  637: ('Nike Lunar Mount Royal Golf Shoes', 29),
#  638: ('Nike Lunar Mount Royal Golf Shoes', 29),
#  639: ("Columbia Men's PFG Terminal Elements Marlin T", 29),
#  640: ("Columbia Men's PFG Fear the Moray T-Shirt", 29),
#  641: ("Columbia Men's PFG Master Caster T-Shirt", 29),
#  642: ("Columbia Men's PFG Anchor Tough T-Shirt", 29),
#  643: ('Nike Lunar Cypress Golf Shoes', 29),
#  644: ('Nike Lunar Cypress Golf Shoes', 29),
#  645: ("Roxy Women's Steamer Long Sleeve Rash Guard", 30),
#  646: ("Merrell Women's Grassbow Sport Hiking Shoe", 30),
#  647: ("Merrell Women's Siren Mid Waterproof Hiking B", 30),
#  648: ("Merrell Women's Siren Mid Waterproof Hiking B", 30),
#  649: ("Merrell Men's Chameleon Prime Stretch Realtre", 30),
#  650: ('"Merrell Men\'s Chameleon Prime Stretch Hiking "', 30),
#  651: ("Merrell Men's Chameleon Prime Stretch Realtre", 30),
#  652: ("Merrell Women's Grassbow Sport Waterproof Hik", 30),
#  653: ("Merrell Women's Grassbow Sport Hiking Shoe", 30),
#  654: ("Merrell Men's Moab Rover Waterproof Wide Hiki", 30),
#  655: ("Merrell Men's Moab Rover Waterproof Wide Hiki", 30),
#  656: ("Merrell Men's Moab Rover Waterproof Wide Hiki", 30),
#  657: ("Merrell Women's Azura Wide Hiking Shoe", 30),
#  658: ("Merrell Women's Azura Hiking Shoe", 30),
#  659: ("Merrell Men's Moab Rover Waterproof Wide Hiki", 30),
#  660: ("Merrell Men's Moab Rover Waterproof Hiking Sh", 30),
#  661: ("Merrell Women's Azura Wide Hiking Shoe", 30),
#  662: ("Merrell Women's Azura Hiking Shoe", 30),
#  663: ('"Merrell Men\'s Moab Rover Mid Waterproof Wide "', 30),
#  664: ('"Merrell Men\'s Moab Rover Mid Waterproof Wide "', 30),
#  665: ("Merrell Men's Moab Rover Mid Waterproof Hikin", 30),
#  666: ("Merrell Men's All Out Flash Trail Running Sho", 30),
#  667: ("Merrell Women's All Out Flash Trail Running S", 30),
#  668: ("Merrell Women's All Out Flash Trail Running S", 30),
#  669: ('Cleveland Golf My Custom Wedge 588 Forged RTX', 31),
#  670: ('Cleveland Golf Elite My Custom Wedge 588 Forg', 31),
#  671: ('Cleveland Golf Collegiate My Custom Wedge 588', 31),
#  672: ('PING G30 Driver', 31),
#  673: ('PING G30 Fairway Wood', 31),
#  674: ('PING G30 Hybrid', 31),
#  675: ('PING G30 Irons - (Steel) 4-UW', 31),
#  676: ('PING G30 Irons - (Graphite) 4-UW', 31),
#  677: ('TaylorMade White Smoke IN-12 Putter', 31),
#  678: ('TaylorMade White Smoke MC-72 Putter', 31),
#  679: ('Tour Edge Exotics CB Pro S Forged Wedge', 31),
#  680: ('Boccieri Golf EL C2-M Counterbalance Putter', 31),
#  681: ('Boccieri Golf EL C2-M Counterbalance Putter', 31),
#  682: ('Boccieri Golf EL L3-M Counterbalance Putter', 31),
#  683: ('Boccieri Golf EL L3-M Counterbalance Putter', 31),
#  684: ('PING Scottsdale TR Anser 2B Counterbalance Pu', 31),
#  685: ('"TaylorMade SLDR Irons - (Steel) 4-PW', 31),
#  686: ('MDGolf Texas Longhorns Putter', 31),
#  687: ('MDGolf Alabama Crimson Tide Putter', 31),
#  688: ('Tour Edge XCG7 Irons - (Steel) 4-PW', 31),
#  689: ('Tour Edge XCG7 Irons - (Graphite) 4-PW', 31),
#  690: ('Tour Edge XCG7 X-LITE Hybrid/Irons - (Graphit', 31),
#  691: ('MDGolf Pittsburgh Penguins Putter', 31),
#  692: ('MDGolf Philadelphia Flyers Putter', 31),
#  693: ('"Top Flite Women\'s XL 12-Piece Complete Set - "', 32),
#  694: ("Callaway Women's Solaire Gems 20-Piece Comple", 32),
#  695: ("Callaway Women's Solaire Gems 20-Piece Comple", 32),
#  696: ("Wilson Women's Profile Petite 11-Piece Comple", 32),
#  697: ("Tour Edge Women's Moda Silk 18-Piece Complete", 32),
#  698: ("Cleveland Women's 588 Altitude Hybrid/Irons -", 32),
#  699: ("Tour Edge Women's Moda Silk 18-Piece Complete", 32),
#  700: ("Top Flite Women's 2014 XL Driver", 32),
#  701: ("Top Flite Women's 2014 XL Fairway", 32),
#  702: ("Top Flite Women's Tour Black PVD Wedge", 32),
#  703: ("Top Flite Women's 2014 XL Hybrid", 32),
#  704: ("Cobra Women's AMP CELL-S Irons - (Graphite) 5", 32),
#  705: ("Cleveland Golf Women's 588 RTX CB Satin Chrom", 32),
#  706: ("Top Flite Women's 2014 1.0 Blade Putter", 32),
#  707: ("Top Flite Women's 2014 2.0 Mallet Putter", 32),
#  708: ("Adams Golf Women's Idea Tech V4 Hybrid/Iron S", 32),
#  709: ("Top Flite Women's Aero Adjustable Driver - Gr", 32),
#  710: ("Top Flite Women's Aero Adjustable Driver - Pi", 32),
#  711: ("Top Flite Women's Aero Fairway", 32),
#  712: ("Top Flite Women's Aero Hybrid", 32),
#  713: ("TaylorMade Women's RBZ SL Driver", 32),
#  714: ("TaylorMade Women's RBZ SL Fairway", 32),
#  715: ("TaylorMade Women's RBZ SL Rescue", 32),
#  716: ('"TaylorMade Women\'s RBZ SL Irons - (Graphite) "', 32),
#  717: ("Under Armour Men's Performance Chino Straight", 33),
#  718: ('Nike Lunarwaverly Golf Shoes', 33),
#  719: ('Nike Lunar Cypress Golf Shoes', 33),
#  720: ("LIJA Women's Eyelet Golf Skort", 33),
#  721: ("LIJA Women's Golf Beanie", 33),
#  722: ("LIJA Women's Golf Hat", 33),
#  723: ("LIJA Women's Golf Visor", 33),
#  724: ("LIJA Women's Mid-Length Panel Golf Shorts", 33),
#  725: ("LIJA Women's Button Golf Dress", 33),
#  726: ("LIJA Women's Ace Sleeveless Golf Polo", 33),
#  727: ("LIJA Women's Long Sleeve Golf Quarter-Zip Pul", 33),
#  728: ("LIJA Women's Eyelet Sleeveless Golf Polo", 33),
#  729: ("LIJA Women's Open Neck Print Golf Polo", 33),
#  730: ("LIJA Women's Argyle Golf Polo", 33),
#  731: ("LIJA Women's Mandarin Sleeveless Golf Polo", 33),
#  732: ("LILJA Women's Ace Golf Polo", 33),
#  733: ("Nike Women's Lunar Empress Golf Shoes", 33),
#  734: ("Black Clover Men's Premium Clover Mesh Back G", 33),
#  735: ("Black Clover Men's Premium Clover Mesh Back G", 33),
#  736: ("Black Clover Men's Premium Clover Fitted Golf", 33),
#  737: ("Black Clover Men's Premium Clover Flex Fit Go", 33),
#  738: ("Sport Haley Women's Embossed Golf Polo", 33),
#  739: ('Nike TW 14 Mesh Golf Shoes', 33),
#  740: ('Nike TW 14 Mesh Golf Shoes', 33),
#  741: ('FootJoy GreenJoys Golf Shoes', 34),
#  742: ('FootJoy GreenJoys Golf Shoes', 34),
#  743: ('Ogio Race Golf Shoes', 34),
#  744: ('Ogio Race Golf Shoes', 34),
#  745: ('Ogio City Spiked Golf Shoes', 34),
#  746: ('Ogio City Spiked Golf Shoes', 34),
#  747: ('Ogio City Spiked Golf Shoes', 34),
#  748: ('Ogio City Turf Golf Shoes', 34),
#  749: ('Ogio City Turf Golf Shoes', 34),
#  750: ('Ogio City Turf Golf Shoes', 34),
#  751: ('Ogio Sport Golf Shoes', 34),
#  752: ('Ogio Sport Golf Shoes', 34),
#  753: ('Ogio Sport Golf Shoes', 34),
#  754: ('TRUE linkswear Lyt Dry Golf Shoes', 34),
#  755: ('TRUE linkswear Lyt Dry Golf Shoes', 34),
#  756: ('TRUE linkswear Lyt Dry Golf Shoes', 34),
#  757: ('TRUE linkswear Vegas Golf Shoes', 34),
#  758: ('TRUE linkswear Vegas Golf Shoes', 34),
#  759: ('Nike Lunarwaverly Golf Shoes', 34),
#  760: ('Nike Lunarwaverly Golf Shoes', 34),
#  761: ('Nike Lunarwaverly Golf Shoes', 34),
#  762: ('Nike Lunarwaverly Golf Shoes', 34),
#  763: ('PING Golf Shoe Bag', 34),
#  764: ('Nike Lunar Mount Royal Golf Shoes', 34),
#  765: ('"Club Glove Burst Proof with Wheels II Travel "', 35),
#  766: ('Club Glove Last Bag', 35),
#  767: ('Callaway 2014 Limited-Edition Hyper-Lite 5 St', 35),
#  768: ('Titleist Club Glove Travel Cover', 35),
#  769: ('Clicgear Rovic Wheel Cover', 35),
#  770: ('Clicgear Rovic Cart Seat', 35),
#  771: ('Clicgear Rovic Cooler Bag', 35),
#  772: ('Clicgear Rovic Shoe Brush', 35),
#  773: ('Titleist Small Wheeled Travel Cover', 35),
#  774: ('Clicgear 8.0 Pack Sack', 35),
#  775: ('Clicgear 8.0 Shoe Brush', 35),
#  776: ('Bag Boy C3 Push Cart', 35),
#  777: ('Bag Boy M330 Push Cart', 35),
#  778: ('Bag Boy Beverage Holder', 35),
#  779: ('Bag Boy Cart Seat', 35),
#  780: ('Bag Boy Express DLX Pro Push Cart', 35),
#  781: ('TaylorMade Performance Travel Cover', 35),
#  782: ('Maxfli Tour Travel Cover', 35),
#  783: ('Titleist 2014 Lightweight Stand Bag', 35),
#  784: ('Bag Boy Hybrid Pivot Grip Travel Cover', 35),
#  785: ('PING 2014 Hoofer 14 Stand Bag', 35),
#  786: ('TaylorMade 2014 Purelite Stand Bag', 35),
#  787: ('Nike 2014 Air Sport Stand Bag', 35),
#  788: ('Titleist 2014 14-Way Stand Bag', 35),
#  789: ("TaylorMade Men's Burner LTD Golf Glove", 36),
#  790: ("FootJoy Men's StaCool Golf Glove", 36),
#  791: ("Hirzl Women's Trust Feel Golf Glove", 36),
#  792: ("Hirzl Men's Hybrid Golf Glove", 36),
#  793: ("Hirzl Women's Hybrid Golf Glove", 36),
#  794: ("Hirzl Women's Trust Control Golf Glove", 36),
#  795: ("Hirzl Men's Soffft Flex Golf Glove", 36),
#  796: ("Callaway Women's X-Tech Golf Glove - White/Pi", 36),
#  797: ("Hirzl Women's Soffft Flex Golf Glove", 36),
#  798: ("Glove It Women's Urban Brick Golf Glove", 36),
#  799: ("Glove It Women's Versailles Golf Glove", 36),
#  800: ("Glove It Women's Navy Clear Dot Golf Glove", 36),
#  801: ("Glove It Women's Pink Clear Dot Golf Glove", 36),
#  802: ("Glove It Women's Olive Bling Golf Glove", 36),
#  803: ("Glove It Women's Silver Bling Golf Glove", 36),
#  804: ("Glove It Women's Imperial Golf Glove", 36),
#  805: ("Glove It Women's Red Clear Dot Golf Glove", 36),
#  806: ("Glove It Women's Violet Bling Golf Glove", 36),
#  807: ("Glove It Women's Hot Pink Bling Golf Glove", 36),
#  808: ("Glove It Women's Calypso Golf Glove", 36),
#  809: ("Glove It Women's 19th Hole Golf Glove", 36),
#  810: ("Glove It Women's Mod Oval Golf Glove", 36),
#  811: ("Glove It Women's Silver Willow Golf Glove", 36),
#  812: ("Glove It Women's Trellis Golf Glove", 36),
#  813: ('Callaway HX Practice Golf Balls - 18 Pack', 37),
#  814: ('Callaway HX Practice Golf Balls - 9 Pack', 37),
#  815: ('Zero Friction Practice Golf Balls - 12 Pack', 37),
#  816: ('Titleist Pro V1 Golf Balls', 37),
#  817: ('Titleist Pro V1 Personalized Golf Balls', 37),
#  818: ('Titleist Pro V1x Golf Balls', 37),
#  819: ('Titleist Pro V1x Personalized Golf Balls', 37),
#  820: ('Titleist Pro V1 High Numbers Golf Balls', 37),
#  821: ('Titleist Pro V1 High Numbers Personalized Gol', 37),
#  822: ('Titleist Pro V1x High Numbers Golf Balls', 37),
#  823: ('Titleist Pro V1x High Numbers Personalized Go', 37),
#  824: ('Titleist Pro V1 Double Number Golf Balls', 37),
#  825: ('Bridgestone e6 Straight Distance NFL Tennesse', 37),
#  826: ('Bridgestone e6 Straight Distance NFL Tampa Ba', 37),
#  827: ('"Bridgestone e6 Straight Distance NFL Seattle "', 37),
#  828: ('Bridgestone e6 Straight Distance NFL San Dieg', 37),
#  829: ('Bridgestone e6 Straight Distance NFL San Fran', 37),
#  830: ('Bridgestone e6 Straight Distance NFL Miami Do', 37),
#  831: ('Bridgestone e6 Straight Distance NFL Jacksonv', 37),
#  832: ('Bridgestone e6 Straight Distance NFL Indianap', 37),
#  833: ('"Bridgestone e6 Straight Distance NFL Houston "', 37),
#  834: ('"Bridgestone e6 Straight Distance NFL Detroit "', 37),
#  835: ('Bridgestone e6 Straight Distance NFL Carolina', 37),
#  836: ('Bridgestone e6 Straight Distance NFL Baltimor', 37),
#  837: ('Voice Caddie SC100 Portable Golf Launch Monit', 38),
#  838: ('Voice Caddie SC100 Portable Golf Launch Monit', 38),
#  839: ('GolfBuddy VS4 Golf GPS', 38),
#  840: ('Zepp Golf Swing Analyzer', 38),
#  841: ('SkyCaddie LINX Golf GPS Watch', 38),
#  842: ('Bushnell 2014 Tour V3 Patriot Pack Laser Rang', 38),
#  843: ('Bushnell 2014 Tour V3 Slope Patriot Pack Lase', 38),
#  844: ('SkyCaddie LINX Golf GPS Watch', 38),
#  845: ('Garmin Approach S4 Golf GPS Watch', 38),
#  846: ('geckobrands iPhone Waterproof Dry Bag', 38),
#  847: ('geckobrands Galaxy Waterproof Dry Bag', 38),
#  848: ('geckobrands Galaxy Waterproof Dry Bag', 38),
#  849: ('geckobrands Galaxy Waterproof Dry Bag', 38),
#  850: ('geckobrands Galaxy Waterproof Dry Bag', 38),
#  851: ('geckobrands iPhone Waterproof Dry Bag', 38),
#  852: ('geckobrands iPhone Waterproof Dry Bag', 38),
#  853: ('geckobrands iPhone Waterproof Dry Bag', 38),
#  854: ('Maxfli Digital Golf Scope', 38),
#  855: ('Nikon COOLSHOT AS Slope Laser Rangefinder', 38),
#  856: ('Nikon COOLSHOT Laser Rangefinder', 38),
#  857: ('GolfBuddy PT4 Touchscreen GPS', 38),
#  858: ('GolfBuddy VT3 GPS Watch', 38),
#  859: ('Garmin Approach G8 Golf GPS', 38),
#  860: ('Bushnell Pro X7 Jolt Slope Rangefinder', 38),
#  861: ('"Cobra Junior Kids\' Complete Set (Height 53\'\' "', 39),
#  862: ('"Cobra Junior Kids\' Complete Set (Height 46\'\' "', 39),
#  863: ("Top Flite Kids' 2014 XLj Complete Set (Height", 39),
#  864: ("Top Flite Kids' 2014 XLj Complete Set (Height", 39),
#  865: ("Top Flite Kids' 2014 XLj Complete Set (Height", 39),
#  866: ("Top Flite Kids' 2014 XLj Complete Set (Height", 39),
#  867: ("Top Flite Kids' 2014 XLj Complete Set (Height", 39),
#  868: ("Top Flite Kids' XLj Driver (Height 53'' and a", 39),
#  869: ("Top Flite Kids' XLj 7 Iron (Height 53'' and a", 39),
#  870: ("Top Flite Kids' XLj Sand Wedge (Height 53'' a", 39),
#  871: ("Top Flite Kids' XLj Putter (Height 53'' and a", 39),
#  872: ("Top Flite Kids' XLj Driver (Height 46''-52'')", 39),
#  873: ("Top Flite Kids' XLj 7 Iron (Height 46'' - 52'", 39),
#  874: ("Top Flite Kids' XLj Sand Wedge (Height 46'' t", 39),
#  875: ("Top Flite Kids' XLj Putter (Height 46'' - 52'", 39),
#  876: ("Top Flite Kids' XLj Driver (Height 45'' and u", 39),
#  877: ("Top Flite Kids' XLj 7 Iron (Height 45'' and u", 39),
#  878: ("Top Flite Kids' XLj Sand Wedge (Height 45'' a", 39),
#  879: ("Top Flite Kids' XLj Putter (Height 45'' and u", 39),
#  880: ("PING Kids' My First Putter", 39),
#  881: ("Tour Edge Kids' HT Max-J Complete Set (Height", 39),
#  882: ("Tour Edge Kids' HT Max-J Complete Set (Height", 39),
#  883: ("Tour Edge Girls' HT Max-J Complete Set (Heigh", 39),
#  884: ("Tour Edge Girls' HT Max-J Complete Set (Heigh", 39),
#  885: ('Team Golf St. Louis Cardinals Putter Grip', 40),
#  886: ('Team Golf San Francisco Giants Putter Grip', 40),
#  887: ('Team Golf New York Yankees Putter Grip', 40),
#  888: ('Team Golf Detroit Tigers Putter Grip', 40),
#  889: ('Team Golf Chicago Cubs Putter Grip', 40),
#  890: ('Team Golf Boston Red Sox Putter Grip', 40),
#  891: ('Team Golf Washington Redskins Putter Grip', 40),
#  892: ('Team Golf San Francisco 49ers Putter Grip', 40),
#  893: ('Team Golf Pittsburgh Steelers Putter Grip', 40),
#  894: ('Team Golf Dallas Cowboys Putter Grip', 40),
#  895: ('Team Golf Oakland Raiders Putter Grip', 40),
#  896: ('Team Golf New York Giants Putter Grip', 40),
#  897: ('Team Golf New England Patriots Putter Grip', 40),
#  898: ('Team Golf Minnesota Vikings Putter Grip', 40),
#  899: ('Team Golf Green Bay Packers Putter Grip', 40),
#  900: ('Team Golf Chicago Bears Putter Grip', 40),
#  901: ('Team Golf Baltimore Ravens Putter Grip', 40),
#  902: ('Team Golf West Virginia Mountaineers Putter G', 40),
#  903: ('Team Golf Missouri Tigers Putter Grip', 40),
#  904: ('Team Golf Wisconsin Badgers Putter Grip', 40),
#  905: ('Team Golf Texas Longhorns Putter Grip', 40),
#  906: ('Team Golf Tennessee Volunteers Putter Grip', 40),
#  907: ('Team Golf South Carolina Gamecocks Putter Gri', 40),
#  908: ('Team Golf Penn State Nittany Lions Putter Gri', 40),
#  909: ('PING Golf Shoe Bag', 41),
#  910: ("LIJA Women's Golf Beanie", 41),
#  911: ("LIJA Women's Golf Hat", 41),
#  912: ("LIJA Women's Golf Visor", 41),
#  913: ('Golf Pride Decade MultiCompound Platinum Stan', 41),
#  914: ('Golf Pride Decade MultiCompound Platinum Stan', 41),
#  915: ('Golf Pride Decade MultiCompound Platinum Stan', 41),
#  916: ('"Glove It Women\'s Urban Brick 3-Zip Carry All "', 41),
#  917: ("Glove It Women's Mod Oval 3-Zip Carry All Gol", 41),
#  918: ("Glove It Women's Calypso 3-Zip Carry All Golf", 41),
#  919: ("Glove It Women's Imperial 3-Zip Carry All Gol", 41),
#  920: ("Glove It Women's Silver Willow 3-Zip Carry Al", 41),
#  921: ("Glove It Women's Santa Cruz 3-Zip Carry All G", 41),
#  922: ("Glove It Women's Trellis 3-Zip Carry All Golf", 41),
#  923: ("Glove It Women's Leopard 3-Zip Carry All Golf", 41),
#  924: ('Glove It Urban Brick Golf Towel', 41),
#  925: ('Glove It Mod Oval Golf Towel', 41),
#  926: ('Glove It Imperial Golf Towel', 41),
#  927: ('Glove It Silver Willow Golf Towel', 41),
#  928: ('Glove It Santa Cruz Golf Towel', 41),
#  929: ('Glove It Trellis Golf Towel', 41),
#  930: ('Glove It Nine and Wine Golf Towel', 41),
#  931: ("Glove It Women's Perforated 3-Zip Carry All G", 41),
#  932: ("Glove It Women's Pink Snake 3-Zip Carry All G", 41),
#  933: ('Nike VR_S Covert Driver', 42),
#  934: ('Callaway X Hot Driver', 42),
#  935: ('TaylorMade RocketBallz Stage 2 Driver', 42),
#  936: ('Cleveland Golf Classic XL Driver', 42),
#  937: ('Cobra AMP Cell Driver - Orange', 42),
#  938: ('Diamondback Adult Sorrento Mountain Bike 2014', 43),
#  939: ('Nike+ Fuelband SE', 43),
#  940: ("Diamondback Boys' Insight 24 Performance Hybr", 43),
#  941: ("Diamondback Girls' Clarity 24 Hybrid Bike 201", 43),
#  942: ('Diamondback Adult Outlook Mountain Bike 2014', 43),
#  943: ('Diamondback Adult Response XE Mountain Bike 2', 43),
#  944: ('GoPro HERO3+ Black Edition Camera', 43),
#  945: ("Rollerblade Men's Spark 84 Inline Skate", 43),
#  946: ('Diamondback Adult Wildwood Citi Classic Comfo', 43),
#  947: ('Diamondback Adult Edgewood Hybrid Bike 2014', 43),
#  948: ("Rollerblade Women's Spark 84 Inline Skates", 43),
#  949: ('Thule Trailway 4-Bike Hitch Vehicle Rack', 43),
#  950: ('Diamondback Grind BMX Bike 2014', 43),
#  951: ("Diamondback Women's Vital 2 Hybrid Bike 2014", 43),
#  952: ('Yakima DoubleDown Ace Hitch Mount 4-Bike Rack', 43),
#  953: ('Diamondback Adult Trace Hybrid Bike 2014', 43),
#  954: ("Nishiki Women's Tamarack Comfort Bike 2014", 43),
#  955: ("Diamondback Women's Clarity Hybrid Bike 2013", 43),
#  956: ('Diamondback Adult Wildwood Classic Comfort Bi', 43),
#  957: ("Diamondback Women's Serene Classic Comfort Bi", 43),
#  958: ('Nishiki Adult Montour Hybrid Bike 2014', 43),
#  959: ('Diamondback Adult Insight Hybrid Bike 2013', 43),
#  960: ('Saris Bones 2-Bike Rack', 43),
#  961: ("Diamondback Women's Clarity 1 Hybrid Bike 201", 43),
#  962: ('Quest Q64 10 FT. x 10 FT. Slant Leg Instant U', 44),
#  963: ('MAC Sports Collapsible Wagon', 44),
#  964: ('Coleman River Gorge 6 Person Dome Tent', 44),
#  965: ('ENO DoubleNest Two Person Hammock', 44),
#  966: ('Quik Shade Summit SX170 10 FT. x 10 FT. Canop', 44),
#  967: ('Kijaro Dual Lock Chair', 44),
#  968: ("Quest 12' x 12' Dome Canopy", 44),
#  969: ('Coleman River Gorge 8 Person Tent', 44),
#  970: ("Quest Q100 10' X 10' Dome Canopy", 44),
#  971: ('SKLZ Sport-Brella XL', 44),
#  972: ("E-Z Up Vista 12' x 12' Recreational Instant S", 44),
#  973: ('Kijaro XXL Dual Lock Oversized Chair', 44),
#  974: ("The North Face Women's Stinson Rain Jacket", 44),
#  975: ('Eureka! Tetragon 5 Five Person Tent', 44),
#  976: ("Columbia Women's Sandy River Shorts", 44),
#  977: ('ENO Atlas Hammock Straps', 44),
#  978: ('YETI Tundra 65 Chest Cooler', 44),
#  979: ("Quest 12' x 12' Screen House", 44),
#  980: ('Quest Oversized Arm Chair', 44),
#  981: ("The North Face Women's Recon Backpack", 44),
#  982: ('insta-bed Neverflat Air Mattress', 44),
#  983: ('YETI Roadie 20 Chest Cooler', 44),
#  984: ('Quest Eagle Peak 6 Person Tent', 44),
#  985: ('Coleman RoadTrip LXE Grill', 44),
#  986: ("Under Armour Men's Highlight MC Football Clea", 45),
#  987: ('GoPro HERO3+ Black Edition Camera', 45),
#  988: ("Under Armour Men's Ignite Camo II Slide", 45),
#  989: ("Under Armour Men's Highlight MC Football Clea", 45),
#  990: ('Under Armour WWP Freedom Flag T-Shirt', 45),
#  991: ('Bushnell 2014 Tour V3 Patriot Pack Laser Rang', 45),
#  992: ("Under Armour Men's Highlight MC Football Clea", 45),
#  993: ("Under Armour Men's Highlight MC Football Clea", 45),
#  994: ('Primos Truth Cam Supercharged Blackout 7 MP G', 45),
#  995: ('Bushnell 2014 Tour V3 Slope Patriot Pack Lase', 45),
#  996: ('Bushnell Golf Tour v3 Patriot Pack Laser Rang', 45),
#  997: ("Under Armour Men's Highlight MC Football Clea", 45),
#  998: ('Bushnell NEO-X Golf GPS Watch', 45),
#  999: ('"Timberland PRO Men\'s Pit Boss 6"" Steel Toe Wo"', 45),
#  1000: ('Nikon Monarch 5 10x42 Binoculars', 45),
#  ...}

# %%
broadcast_products.value.get(218)
# Out:
# ('Elevation Training Mask 2.0', 11)

# %% [markdown]
# ## ---> Reading Categories

# %%
def read_categories():
    categories_text_wrapper = open("data/retail_db/categories.csv", "r", encoding="utf-8")
    categories = categories_text_wrapper.readlines()
    category_id_name = {}
    
    for line in categories:
        if "categoryName" not in line:
            category_id = int(line.split(",")[0])
            category_name = line.split(",")[2]
            category_id_name.update({category_id: category_name.rstrip()})
            
    return category_id_name

# %%
categories = read_categories()

# %%
broadcast_categories = sc.broadcast(categories)

# %%
broadcast_categories.value
# Out:
# {1: 'Football',
#  2: 'Soccer',
#  3: 'Baseball & Softball',
#  4: 'Basketball',
#  5: 'Lacrosse',
#  6: 'Tennis & Racquet',
#  7: 'Hockey',
#  8: 'More Sports',
#  9: 'Cardio Equipment',
#  10: 'Strength Training',
#  11: 'Fitness Accessories',
#  12: 'Boxing & MMA',
#  13: 'Electronics',
#  14: 'Yoga & Pilates',
#  15: 'Training by Sport',
#  16: 'As Seen on  TV!',
#  17: 'Cleats',
#  18: "Men's Footwear",
#  19: "Women's Footwear",
#  20: "Kids' Footwear",
#  21: 'Featured Shops',
#  22: 'Accessories',
#  23: "Men's Apparel",
#  24: "Women's Apparel",
#  25: "Boys' Apparel",
#  26: "Girls' Apparel",
#  27: 'Accessories',
#  28: 'Top Brands',
#  29: 'Shop By Sport',
#  30: "Men's Golf Clubs",
#  31: "Women's Golf Clubs",
#  32: 'Golf Apparel',
#  33: 'Golf Shoes',
#  34: 'Golf Bags & Carts',
#  35: 'Golf Gloves',
#  36: 'Golf Balls',
#  37: 'Electronics',
#  38: "Kids' Golf Clubs",
#  39: 'Team Shop',
#  40: 'Accessories',
#  41: 'Trade-In',
#  42: 'Bike & Skate Shop',
#  43: 'Camping & Hiking',
#  44: 'Hunting & Shooting',
#  45: 'Fishing',
#  46: 'Indoor/Outdoor Games',
#  47: 'Boating',
#  48: 'Water Sports',
#  49: 'MLB',
#  50: 'NFL',
#  51: 'NHL',
#  52: 'NBA',
#  53: 'NCAA',
#  54: 'MLS',
#  55: 'International Soccer',
#  56: 'World Cup Shop',
#  57: 'MLB Players',
#  58: 'NFL Players'}

# %%
broadcast_categories.value.get(58)
# Out:
# 'NFL Players'

# %%
for i in range(1):
    print(broadcast_categories.value)
# Out:
# {1: 'Football', 2: 'Soccer', 3: 'Baseball & Softball', 4: 'Basketball', 5: 'Lacrosse', 6: 'Tennis & Racquet', 7: 'Hockey', 8: 'More Sports', 9: 'Cardio Equipment', 10: 'Strength Training', 11: 'Fitness Accessories', 12: 'Boxing & MMA', 13: 'Electronics', 14: 'Yoga & Pilates', 15: 'Training by Sport', 16: 'As Seen on  TV!', 17: 'Cleats', 18: "Men's Footwear", 19: "Women's Footwear", 20: "Kids' Footwear", 21: 'Featured Shops', 22: 'Accessories', 23: "Men's Apparel", 24: "Women's Apparel", 25: "Boys' Apparel", 26: "Girls' Apparel", 27: 'Accessories', 28: 'Top Brands', 29: 'Shop By Sport', 30: "Men's Golf Clubs", 31: "Women's Golf Clubs", 32: 'Golf Apparel', 33: 'Golf Shoes', 34: 'Golf Bags & Carts', 35: 'Golf Gloves', 36: 'Golf Balls', 37: 'Electronics', 38: "Kids' Golf Clubs", 39: 'Team Shop', 40: 'Accessories', 41: 'Trade-In', 42: 'Bike & Skate Shop', 43: 'Camping & Hiking', 44: 'Hunting & Shooting', 45: 'Fishing', 46: 'Indoor/Outdoor Games', 47: 'Boating', 48: 'Water Sports', 49: 'MLB', 50: 'NFL', 51: 'NHL', 52: 'NBA', 53: 'NCAA', 54: 'MLS', 55: 'International Soccer', 56: 'World Cup Shop', 57: 'MLB Players', 58: 'NFL Players'}

# %% [markdown]
# ## ---> Reading Orders
# #### Taking only completed order and (orderId, customerId)

# %%
def read_orders():
    orders_text_wrapper = open("data/retail_db/orders.csv", "r", encoding="utf-8")
    orders = orders_text_wrapper.readlines()
    orders_orderId_customerId = {}
    
    for line in orders:
        if "orderId" not in line:
            if "COMPLETE" in line:
                order_id = int(line.split(",")[0])
                customer_id = int(line.split(",")[2])
                orders_orderId_customerId.update({order_id: customer_id})
            
    return orders_orderId_customerId

# %%
orders = read_orders()

# %%
broadcast_orders = sc.broadcast(orders)

# %%
print("(orderId, customerId)")
broadcast_orders.value
# Out:
# (orderId, customerId)
# {3: 12111,
#  5: 11318,
#  6: 7130,
#  7: 4530,
#  15: 2568,
#  17: 2667,
#  22: 333,
#  26: 7562,
#  28: 656,
#  32: 3960,
#  35: 4840,
#  45: 2636,
#  56: 10519,
#  63: 1148,
#  65: 5903,
#  67: 1406,
#  71: 8646,
#  72: 4349,
#  76: 6898,
#  80: 3007,
#  83: 1265,
#  88: 3809,
#  91: 8912,
#  92: 6932,
#  95: 9032,
#  98: 5243,
#  102: 8027,
#  105: 8220,
#  107: 1845,
#  110: 2746,
#  114: 2091,
#  118: 1737,
#  124: 2374,
#  126: 610,
#  135: 7738,
#  137: 4211,
#  139: 7933,
#  141: 12128,
#  143: 10495,
#  146: 8177,
#  149: 11431,
#  152: 3611,
#  153: 8876,
#  160: 6762,
#  163: 3348,
#  171: 1980,
#  172: 11382,
#  174: 3358,
#  175: 384,
#  178: 8503,
#  179: 6506,
#  182: 10984,
#  183: 12105,
#  184: 210,
#  186: 1104,
#  207: 11643,
#  210: 10102,
#  214: 3925,
#  218: 3935,
#  220: 1383,
#  225: 11275,
#  231: 3960,
#  233: 12316,
#  236: 9785,
#  239: 5058,
#  247: 173,
#  248: 11707,
#  250: 11668,
#  252: 9708,
#  253: 45,
#  254: 9395,
#  255: 10346,
#  258: 1137,
#  259: 3454,
#  261: 5128,
#  263: 8026,
#  264: 230,
#  266: 11085,
#  270: 5689,
#  271: 815,
#  279: 10372,
#  283: 11466,
#  287: 8122,
#  288: 8667,
#  290: 6446,
#  296: 6665,
#  298: 4967,
#  301: 11999,
#  302: 3577,
#  304: 1869,
#  306: 137,
#  309: 10396,
#  310: 1256,
#  311: 410,
#  312: 1122,
#  317: 1450,
#  319: 10445,
#  322: 2864,
#  324: 76,
#  328: 1149,
#  330: 5175,
#  332: 4171,
#  337: 6747,
#  338: 4666,
#  343: 10952,
#  346: 3646,
#  347: 11662,
#  348: 12120,
#  349: 9103,
#  350: 10672,
#  351: 12049,
#  357: 2685,
#  360: 8020,
#  368: 5783,
#  369: 189,
#  372: 776,
#  385: 10667,
#  388: 2790,
#  389: 4435,
#  395: 3934,
#  403: 4178,
#  405: 9498,
#  406: 9023,
#  412: 9397,
#  416: 1561,
#  418: 4269,
#  420: 4632,
#  422: 9664,
#  426: 10419,
#  427: 6681,
#  428: 3487,
#  432: 1197,
#  437: 5351,
#  438: 8256,
#  439: 9353,
#  440: 7290,
#  442: 8098,
#  444: 10004,
#  448: 7167,
#  452: 5128,
#  458: 5358,
#  459: 3687,
#  463: 8709,
#  464: 7114,
#  468: 7305,
#  473: 5359,
#  478: 7657,
#  479: 11138,
#  490: 9709,
#  493: 1180,
#  495: 7242,
#  496: 615,
#  497: 846,
#  499: 8920,
#  502: 7196,
#  504: 6288,
#  508: 6970,
#  509: 10739,
#  512: 12000,
#  513: 10479,
#  516: 9204,
#  518: 5257,
#  519: 4780,
#  520: 8074,
#  521: 6497,
#  522: 12300,
#  523: 4477,
#  524: 7622,
#  526: 7259,
#  533: 6770,
#  534: 6896,
#  535: 66,
#  537: 10437,
#  540: 121,
#  541: 4985,
#  545: 11642,
#  547: 7220,
#  551: 2867,
#  553: 7307,
#  556: 7838,
#  557: 4855,
#  558: 4562,
#  573: 5964,
#  576: 7191,
#  588: 6348,
#  589: 5609,
#  591: 6431,
#  599: 8005,
#  600: 3506,
#  601: 8977,
#  602: 6690,
#  605: 2879,
#  606: 1157,
#  608: 10388,
#  611: 8422,
#  613: 460,
#  615: 2827,
#  620: 11346,
#  621: 7916,
#  629: 6772,
#  630: 3449,
#  633: 12249,
#  634: 4588,
#  639: 1072,
#  642: 7499,
#  645: 2238,
#  647: 12319,
#  654: 286,
#  659: 6006,
#  662: 11165,
#  664: 4469,
#  666: 993,
#  674: 1295,
#  675: 3414,
#  682: 9271,
#  697: 3126,
#  698: 5283,
#  700: 2632,
#  704: 11708,
#  714: 4756,
#  718: 70,
#  720: 3142,
#  726: 5407,
#  727: 1049,
#  728: 5965,
#  729: 8467,
#  730: 3189,
#  732: 7633,
#  735: 9142,
#  736: 8536,
#  739: 5647,
#  741: 7481,
#  742: 9860,
#  744: 2960,
#  746: 9753,
#  748: 1198,
#  754: 6699,
#  755: 1478,
#  756: 8441,
#  759: 3328,
#  761: 9748,
#  763: 943,
#  764: 8625,
#  766: 12328,
#  768: 8123,
#  770: 12146,
#  771: 9026,
#  774: 11421,
#  778: 5759,
#  780: 2016,
#  782: 12213,
#  785: 8191,
#  789: 17,
#  794: 7683,
#  795: 7219,
#  798: 8709,
#  800: 9946,
#  802: 1670,
#  806: 11113,
#  807: 1231,
#  814: 11988,
#  819: 1714,
#  821: 8384,
#  822: 1492,
#  826: 3744,
#  831: 12064,
#  832: 132,
#  835: 10640,
#  839: 377,
#  840: 5123,
#  848: 6018,
#  854: 4186,
#  858: 9137,
#  859: 3432,
#  860: 9725,
#  861: 3164,
#  862: 1299,
#  863: 6081,
#  864: 12342,
#  867: 6669,
#  871: 6923,
#  872: 6440,
#  878: 207,
#  879: 3031,
#  880: 5400,
#  881: 3291,
#  882: 4102,
#  883: 4305,
#  884: 4909,
#  885: 7706,
#  886: 2124,
#  889: 3677,
#  890: 8908,
#  891: 5609,
#  893: 3106,
#  907: 10661,
#  910: 2762,
#  911: 3608,
#  914: 6484,
#  917: 9901,
#  919: 10890,
#  920: 12019,
#  923: 5511,
#  925: 937,
#  927: 2520,
#  928: 2487,
#  931: 10514,
#  933: 446,
#  934: 2931,
#  936: 7202,
#  938: 7802,
#  941: 842,
#  942: 9704,
#  943: 2346,
#  945: 9732,
#  946: 10961,
#  952: 2250,
#  958: 12050,
#  960: 1463,
#  964: 3397,
#  966: 11298,
#  969: 9247,
#  977: 7817,
#  979: 11323,
#  981: 5411,
#  985: 5389,
#  987: 7418,
#  988: 2491,
#  990: 7254,
#  992: 7107,
#  995: 10907,
#  997: 8786,
#  1001: 6650,
#  1003: 7438,
#  1004: 10701,
#  1006: 9028,
#  1009: 7886,
#  1010: 2512,
#  1011: 7214,
#  1018: 19,
#  1021: 10118,
#  1024: 3751,
#  1026: 800,
#  1030: 11178,
#  1031: 633,
#  1032: 7246,
#  1034: 4990,
#  1035: 9117,
#  1038: 5418,
#  1039: 1558,
#  1040: 5787,
#  1051: 6397,
#  1055: 8971,
#  1056: 11006,
#  1075: 2735,
#  1076: 7320,
#  1077: 8103,
#  1081: 2932,
#  1091: 7042,
#  1096: 458,
#  1097: 1030,
#  1098: 11983,
#  1099: 2653,
#  1106: 2106,
#  1111: 225,
#  1112: 7877,
#  1119: 2267,
#  1125: 7287,
#  1126: 6649,
#  1128: 1498,
#  1132: 8386,
#  1134: 4181,
#  1135: 5359,
#  1138: 10777,
#  1143: 9715,
#  1146: 4044,
#  1148: 6596,
#  1149: 8767,
#  1154: 3554,
#  1162: 5195,
#  1163: 965,
#  1164: 7009,
#  1165: 5885,
#  1173: 5645,
#  1174: 8290,
#  1175: 1330,
#  1176: 10952,
#  1182: 6438,
#  1188: 8957,
#  1196: 2737,
#  1197: 5003,
#  1200: 11994,
#  1203: 2447,
#  1205: 11907,
#  1206: 6083,
#  1215: 2660,
#  1217: 5328,
#  1223: 7981,
#  1225: 665,
#  1226: 9643,
#  1230: 11855,
#  1238: 2610,
#  1240: 749,
#  1241: 7430,
#  1244: 10480,
#  1246: 9098,
#  1247: 10436,
#  1250: 6845,
#  1251: 11689,
#  1253: 5633,
#  1254: 1729,
#  1255: 8929,
#  1262: 2972,
#  1265: 8982,
#  1267: 1147,
#  1269: 8069,
#  1273: 3322,
#  1274: 5511,
#  1277: 1939,
#  1281: 10431,
#  1287: 2597,
#  1291: 704,
#  1292: 11460,
#  1297: 11607,
#  1299: 7802,
#  1302: 1695,
#  1304: 2059,
#  1305: 3844,
#  1307: 4474,
#  1312: 12291,
#  1314: 10993,
#  1315: 5660,
#  1318: 4212,
#  1319: 3966,
#  1320: 12270,
#  1321: 800,
#  1322: 9264,
#  1323: 7422,
#  1324: 4600,
#  1327: 9526,
#  1330: 4624,
#  1333: 905,
#  1335: 5762,
#  1337: 3561,
#  1338: 2094,
#  1341: 3119,
#  1342: 8350,
#  1345: 7729,
#  1350: 7006,
#  1353: 1727,
#  1357: 5088,
#  1362: 5661,
#  1367: 2703,
#  1370: 9223,
#  1377: 5418,
#  1382: 9151,
#  1390: 8964,
#  1392: 7102,
#  1400: 478,
#  1405: 8627,
#  1407: 4900,
#  1410: 5928,
#  1422: 8406,
#  1424: 5763,
#  1427: 4795,
#  1430: 5241,
#  1432: 3730,
#  1434: 6607,
#  1439: 11719,
#  1440: 9310,
#  1444: 8302,
#  1445: 2182,
#  1446: 9102,
#  1449: 10783,
#  1452: 4953,
#  1462: 3592,
#  1464: 7510,
#  1466: 7054,
#  1472: 2394,
#  1474: 10365,
#  1481: 5953,
#  1483: 9307,
#  1484: 10601,
#  1489: 2550,
#  1490: 5067,
#  1491: 10029,
#  1501: 4787,
#  1505: 7795,
#  1515: 12346,
#  1519: 5190,
#  1520: 12309,
#  1521: 11622,
#  1522: 5713,
#  1524: 1507,
#  1525: 6592,
#  1530: 1032,
#  1531: 8731,
#  1532: 4646,
#  1535: 2129,
#  1537: 8013,
#  1541: 8024,
#  1547: 9462,
#  1549: 12142,
#  1555: 1831,
#  1557: 1812,
#  1559: 15,
#  1569: 2444,
#  1571: 8047,
#  1572: 353,
#  1577: 7100,
#  1578: 11518,
#  1582: 5828,
#  1587: 3231,
#  1589: 12120,
#  1590: 483,
#  1591: 10666,
#  1596: 6478,
#  1599: 8647,
#  1604: 6008,
#  1605: 6119,
#  1607: 12371,
#  1611: 7387,
#  1612: 11833,
#  1613: 1252,
#  1615: 6088,
#  1618: 9459,
#  1619: 11557,
#  1620: 3010,
#  1624: 9982,
#  1628: 4203,
#  1630: 6222,
#  1633: 8464,
#  1637: 9504,
#  1641: 3158,
#  1648: 2113,
#  1649: 4116,
#  1652: 11821,
#  1653: 9808,
#  1654: 5691,
#  1656: 12352,
#  1660: 2306,
#  1662: 9772,
#  1663: 2062,
#  1664: 1821,
#  1665: 8292,
#  1667: 10096,
#  1670: 10588,
#  1671: 5613,
#  1672: 10602,
#  1673: 10061,
#  1674: 4364,
#  1676: 11641,
#  1677: 11037,
#  1678: 1419,
#  1682: 620,
#  1684: 5913,
#  1694: 3588,
#  1697: 7089,
#  1698: 7882,
#  1701: 5429,
#  1702: 8069,
#  1704: 5310,
#  1706: 3550,
#  1707: 9559,
#  1708: 87,
#  1709: 7736,
#  1711: 1153,
#  1712: 33,
#  1715: 7546,
#  1727: 8630,
#  1729: 7176,
#  1733: 8069,
#  1736: 3685,
#  1737: 3653,
#  1738: 2930,
#  1740: 5986,
#  1741: 8622,
#  1742: 6913,
#  1744: 9782,
#  1745: 10829,
#  1749: 1157,
#  1753: 109,
#  1755: 10457,
#  1768: 9695,
#  1773: 10667,
#  1774: 10109,
#  1775: 12112,
#  1777: 7264,
#  1779: 7372,
#  1782: 12054,
#  1785: 12024,
#  1788: 9281,
#  1789: 2159,
#  1791: 2575,
#  1795: 9128,
#  1799: 3295,
#  1800: 9572,
#  1801: 7329,
#  1802: 5236,
#  1808: 9615,
#  1809: 5847,
#  1813: 719,
#  1815: 475,
#  1816: 2769,
#  1819: 4502,
#  1820: 590,
#  1822: 5682,
#  1825: 5706,
#  1829: 3951,
#  1830: 1012,
#  1832: 7693,
#  1834: 3686,
#  1836: 6874,
#  1841: 3891,
#  1843: 6246,
#  1844: 8800,
#  1846: 4154,
#  1852: 4203,
#  1856: 4220,
#  1858: 12368,
#  1865: 7543,
#  1874: 4761,
#  1875: 10688,
#  1877: 7364,
#  1880: 5040,
#  1881: 9770,
#  1884: 1759,
#  1886: 3550,
#  1887: 3979,
#  1889: 5151,
#  1890: 4539,
#  1898: 11531,
#  1901: 4354,
#  1902: 7678,
#  1917: 11458,
#  1920: 5491,
#  1922: 8052,
#  1923: 10336,
#  1930: 11330,
#  1935: 12189,
#  1938: 6474,
#  1943: 5033,
#  1944: 4043,
#  1949: 11535,
#  1950: 1899,
#  1952: 940,
#  1953: 9524,
#  1954: 6130,
#  1957: 1795,
#  1958: 5093,
#  1965: 5637,
#  1971: 1717,
#  1974: 9342,
#  1975: 6398,
#  1977: 2999,
#  1980: 5579,
#  1982: 7323,
#  1993: 988,
#  1998: 6390,
#  2003: 3811,
#  2005: 3535,
#  2006: 8745,
#  2008: 226,
#  2016: 2462,
#  2020: 3395,
#  2023: 3006,
#  2025: 6415,
#  2026: 118,
#  2028: 1350,
#  2031: 134,
#  2034: 6002,
#  2037: 6949,
#  2040: 844,
#  2043: 9969,
#  2044: 9412,
#  2046: 5032,
#  2048: 9201,
#  2049: 6736,
#  2050: 11240,
#  2051: 3812,
#  2056: 5564,
#  2058: 5573,
#  2059: 11250,
#  2065: 2319,
#  2070: 1959,
#  2073: 3938,
#  2075: 2660,
#  2078: 11149,
#  2080: 9587,
#  2081: 6221,
#  2086: 2154,
#  2088: 8296,
#  2098: 12420,
#  2102: 3087,
#  2105: 10538,
#  2107: 8522,
#  2108: 11963,
#  2109: 13,
#  2113: 8550,
#  2114: 1772,
#  2115: 7981,
#  2118: 337,
#  2119: 11863,
#  2122: 10518,
#  2125: 11318,
#  2127: 3508,
#  2128: 4269,
#  2134: 7428,
#  2137: 1252,
#  2140: 5291,
#  2142: 1594,
#  2143: 107,
#  2146: 4932,
#  2148: 2363,
#  2155: 9371,
#  2161: 183,
#  2163: 11650,
#  2169: 6038,
#  2171: 10462,
#  2172: 1983,
#  2173: 8861,
#  2175: 5344,
#  2176: 3690,
#  2178: 10247,
#  2180: 7393,
#  2182: 2157,
#  2183: 4643,
#  2184: 1480,
#  2185: 9078,
#  2187: 4567,
#  2190: 5868,
#  2192: 3765,
#  2193: 12022,
#  2194: 9818,
#  2195: 679,
#  2198: 1593,
#  2204: 7417,
#  2205: 12043,
#  2210: 3572,
#  2215: 4924,
#  2216: 8965,
#  2217: 6414,
#  2226: 8416,
#  2228: 8624,
#  2230: 5253,
#  2231: 11748,
#  2235: 2336,
#  2238: 6878,
#  2241: 11443,
#  2243: 12091,
#  2245: 11895,
#  2247: 3906,
#  2250: 9874,
#  2255: 838,
#  2267: 1392,
#  2269: 4674,
#  2270: 7805,
#  2273: 133,
#  2274: 6137,
#  2275: 4908,
#  2278: 4427,
#  2279: 5134,
#  2280: 4261,
#  2286: 2534,
#  2287: 6011,
#  2297: 5627,
#  2299: 25,
#  2303: 2440,
#  2304: 6253,
#  2312: 5570,
#  2314: 8165,
#  2316: 5027,
#  2320: 5742,
#  2326: 8716,
#  2335: 6917,
#  2338: 4910,
#  2340: 11579,
#  2342: 9376,
#  2343: 8425,
#  2344: 898,
#  2345: 5086,
#  2346: 6723,
#  2347: 7778,
#  2348: 6525,
#  2351: 5947,
#  2352: 4174,
#  2355: 8319,
#  2356: 349,
#  2357: 550,
#  2358: 11423,
#  2362: 11587,
#  2370: 9705,
#  2372: 3303,
#  2373: 8830,
#  2374: 542,
#  2375: 7604,
#  2383: 4929,
#  2385: 2208,
#  2387: 7623,
#  2389: 10051,
#  2394: 3085,
#  2395: 6311,
#  2401: 4901,
#  2404: 1076,
#  2408: 5266,
#  2413: 1855,
#  2419: 12041,
#  2431: 1256,
#  2437: 11032,
#  2442: 7908,
#  2445: 7683,
#  2447: 5454,
#  2450: 7841,
#  2452: 9233,
#  2453: 11517,
#  2455: 7814,
#  2463: 11991,
#  2472: 6161,
#  2473: 3763,
#  2474: 2027,
#  2477: 9598,
#  2480: 3807,
#  2481: 2476,
#  2483: 10453,
#  2484: 9256,
#  2488: 1255,
#  2491: 247,
#  2495: 9011,
#  2498: 1966,
#  2511: 8544,
#  2515: 12056,
#  2516: 2775,
#  2522: 10999,
#  2523: 5865,
#  2524: 1511,
#  2533: 3034,
#  2540: 9217,
#  2545: 11369,
#  2546: 6775,
#  2554: 11228,
#  2555: 5216,
#  2561: 7253,
#  2562: 1977,
#  2564: 11767,
#  2568: 11800,
#  2569: 687,
#  2570: 6415,
#  2571: 5815,
#  2579: 8491,
#  2582: 1127,
#  2583: 11564,
#  2585: 9821,
#  2586: 6559,
#  2588: 3178,
#  2589: 1429,
#  2591: 2377,
#  2596: 3603,
#  2597: 173,
#  2600: 5653,
#  2601: 11457,
#  2602: 3180,
#  2604: 1298,
#  2607: 1828,
#  2610: 6114,
#  2611: 12086,
#  2613: 10312,
#  2614: 3505,
#  2618: 4879,
#  2622: 3301,
#  2629: 10722,
#  2630: 9619,
#  2631: 1141,
#  2633: 8975,
#  2635: 800,
#  2638: 3816,
#  2640: 7177,
#  2645: 4159,
#  2650: 2118,
#  2651: 839,
#  2654: 11439,
#  2656: 4625,
#  2657: 12081,
#  2658: 8741,
#  2659: 6630,
#  2660: 2234,
#  2662: 1646,
#  2665: 1610,
#  2669: 1286,
#  2670: 6602,
#  2675: 7808,
#  2678: 8971,
#  2682: 4960,
#  2683: 5686,
#  2684: 6750,
#  2688: 5367,
#  2690: 8037,
#  2693: 11208,
#  2694: 8419,
#  2698: 3683,
#  2700: 2701,
#  2702: 5643,
#  2710: 2307,
#  2712: 7562,
#  2715: 3301,
#  2716: 4047,
#  2720: 9463,
#  2722: 6307,
#  2723: 3985,
#  2727: 8910,
#  2729: 6278,
#  2732: 6875,
#  2736: 1261,
#  2746: 5960,
#  2750: 11838,
#  2751: 6745,
#  2755: 1679,
#  2760: 11662,
#  2764: 8738,
#  2766: 3520,
#  2769: 9542,
#  2770: 10056,
#  2775: 10402,
#  2777: 1535,
#  2783: 2615,
#  2785: 1775,
#  2792: 9575,
#  2793: 7652,
#  2794: 7129,
#  2795: 7557,
#  2803: 2434,
#  2805: 9751,
#  2807: 12280,
#  2809: 2813,
#  2810: 1288,
#  2817: 9933,
#  2818: 1201,
#  2825: 1944,
#  2826: 9235,
#  2827: 10607,
#  2829: 7927,
#  2833: 7844,
#  2836: 4819,
#  2842: 6944,
#  2846: 3771,
#  2850: 9412,
#  2851: 3908,
#  2855: 7201,
#  2859: 9494,
#  2867: 3172,
#  2868: 10469,
#  2870: 615,
#  2871: 1766,
#  2874: 10608,
#  2877: 4836,
#  2878: 2083,
#  2879: 12058,
#  2882: 3647,
#  2889: 8885,
#  2890: 3745,
#  2891: 11540,
#  2898: 8432,
#  2900: 10787,
#  2905: 982,
#  2906: 10512,
#  2910: 7593,
#  2913: 444,
#  2920: 11673,
#  2922: 8179,
#  2929: 1044,
#  2932: 9037,
#  2938: 116,
#  2939: 5660,
#  2943: 11539,
#  2950: 3757,
#  2954: 1043,
#  2957: 2025,
#  2963: 11804,
#  2967: 2199,
#  2969: 8603,
#  2971: 3039,
#  2975: 3357,
#  2979: 10882,
#  2983: 3031,
#  2986: 11306,
#  2991: 7989,
#  2995: 6085,
#  2998: 11971,
#  2999: 2309,
#  3002: 2683,
#  3005: 11986,
#  3009: 7789,
#  3010: 10005,
#  3011: 7676,
#  3012: 6593,
#  3013: 550,
#  3017: 5211,
#  3018: 3995,
#  3021: 2277,
#  3022: 9278,
#  3023: 5863,
#  ...}

# %%
len(broadcast_orders.value)
# Out:
# 22899

# %% [markdown]
# ## ---> Reading Customers

# %%
def read_customers():
    customer_text_wrapper = open("data/retail_db/customers.csv", "r", encoding="utf-8")
    customers = customer_text_wrapper.readlines()
    customerId_Dictionary= {}
    
    for line in customers:
        if "customerId" not in line:
            customerId = int(line.split(",")[0])
            customerFirstName = line.split(",")[1]
            customerLastName = line.split(",")[2]
            customerCity = line.split(",")[6]
            customerId_Dictionary.update({customerId: (customerFirstName + ' ' + customerLastName, customerCity)})
            
    return customerId_Dictionary

# %%
customers = read_customers()

# %%
broadcast_customers = sc.broadcast(customers)

# %%
broadcast_customers.value
# Out:
# {1: ('Richard Hernandez', 'Brownsville'),
#  2: ('Mary Barrett', 'Littleton'),
#  3: ('Ann Smith', 'Caguas'),
#  4: ('Mary Jones', 'San Marcos'),
#  5: ('Robert Hudson', 'Caguas'),
#  6: ('Mary Smith', 'Passaic'),
#  7: ('Melissa Wilcox', 'Caguas'),
#  8: ('Megan Smith', 'Lawrence'),
#  9: ('Mary Perez', 'Caguas'),
#  10: ('Melissa Smith', 'Stafford'),
#  11: ('Mary Huffman', 'Caguas'),
#  12: ('Christopher Smith', 'San Antonio'),
#  13: ('Mary Baldwin', 'Caguas'),
#  14: ('Katherine Smith', 'Pico Rivera'),
#  15: ('Jane Luna', 'Fontana'),
#  16: ('Tiffany Smith', 'Caguas'),
#  17: ('Mary Robinson', 'Taylor'),
#  18: ('Robert Smith', 'Martinez'),
#  19: ('Stephanie Mitchell', 'Caguas'),
#  20: ('Mary Ellis', 'West New York'),
#  21: ('William Zimmerman', 'Caguas'),
#  22: ('Joseph Smith', 'North Bergen'),
#  23: ('Benjamin Duarte', 'San Juan'),
#  24: ('Mary Smith', 'Caguas'),
#  25: ('Paul Richardson', 'Peoria'),
#  26: ('Johnny Hood', 'Glenview'),
#  27: ('Mary Vincent', 'Caguas'),
#  28: ('Timothy Smith', 'Longview'),
#  29: ('Mary Humphrey', 'Fort Worth'),
#  30: ('Barbara Smith', 'Caguas'),
#  31: ('Mary Byrd', 'Albuquerque'),
#  32: ('Alice Smith', 'Caguas'),
#  33: ('Adam Petersen', 'Norfolk'),
#  34: ('Mary Smith', 'Caguas'),
#  35: ('Margaret Wright', 'Oceanside'),
#  36: ('Michelle Carey', 'Caguas'),
#  37: ('Virginia Conrad', 'Norfolk'),
#  38: ('Mary Smith', 'Opelousas'),
#  39: ('Juan Mckinney', 'Caguas'),
#  40: ('Mary Smith', 'Long Beach'),
#  41: ('Victoria Mason', 'Brooklyn'),
#  42: ('Ethan Smith', 'Duluth'),
#  43: ('Mary Herring', 'Caguas'),
#  44: ('Howard Smith', 'Napa'),
#  45: ('Mary Nunez', 'Denver'),
#  46: ('Jennifer Smith', 'Freeport'),
#  47: ('Lori Fuller', 'Caguas'),
#  48: ('Mary Cowan', 'Strongsville'),
#  49: ('Martha Smith', 'Caguas'),
#  50: ('Mary Kim', 'San Bernardino'),
#  51: ('Jessica Smith', 'Caguas'),
#  52: ('Mary Lawson', 'Chicago'),
#  53: ('Katherine Smith', 'Roswell'),
#  54: ('Mary Olson', 'Caguas'),
#  55: ('Janet Farley', 'Phoenix'),
#  56: ('Mary Kaiser', 'Caguas'),
#  57: ('Mary Smith', 'Baltimore'),
#  58: ('Michael Edwards', 'Caguas'),
#  59: ('Douglas James', 'Sunnyvale'),
#  60: ('Mary Gutierrez', 'Webster'),
#  61: ('Margaret Summers', 'Caguas'),
#  62: ('Mary Oneal', 'Brooklyn'),
#  63: ('Aaron Smith', 'Caguas'),
#  64: ('Mary Reynolds', 'Chicago'),
#  65: ('Jennifer Smith', 'Princeton'),
#  66: ('Mary Booth', 'Caguas'),
#  67: ('Samantha Smith', 'Chicago'),
#  68: ('Mary Oneal', 'Peoria'),
#  69: ('Megan Smith', 'Caguas'),
#  70: ('Mary Simmons', 'Los Angeles'),
#  71: ('Charles Smith', 'Philadelphia'),
#  72: ('Frank Gillespie', 'Vista'),
#  73: ('Mary Smith', 'Caguas'),
#  74: ('Alice Rush', 'Jacksonville'),
#  75: ('Mary Smith', 'Caguas'),
#  76: ('Joseph Young', 'Los Angeles'),
#  77: ('Shirley Dalton', 'Caguas'),
#  78: ('Jeremy Smith', 'Parkville'),
#  79: ('Mary Watkins', 'Knoxville'),
#  80: ('Joe Parsons', 'Caguas'),
#  81: ('Mary Smith', 'Ithaca'),
#  82: ('Jonathan Cook', 'San Antonio'),
#  83: ('Mary Wong', 'Caguas'),
#  84: ('Douglas Smith', 'Tampa'),
#  85: ('Mary Perez', 'Caguas'),
#  86: ('John Smith', 'Fort Worth'),
#  87: ('Gloria Brown', 'Caguas'),
#  88: ('Mary Henry', 'Atlanta'),
#  89: ('Sean Smith', 'Escondido'),
#  90: ('Mary Hurley', 'Caguas'),
#  91: ('Ashley Smith', 'Spring'),
#  92: ('Alexander Medina', 'Caguas'),
#  93: ('Mary Robbins', 'Annapolis'),
#  94: ('Mary Smith', 'Caguas'),
#  95: ('Susan Williams', 'Hyattsville'),
#  96: ('Virginia Smith', 'Caguas'),
#  97: ('Mary Rhodes', 'Phoenix'),
#  98: ('William Smith', 'Caguas'),
#  99: ('Betty Munoz', 'Las Vegas'),
#  100: ('George Barrett', 'Caguas'),
#  101: ('Mary Briggs', 'Dorchester Center'),
#  102: ('Gregory Smith', 'Caguas'),
#  103: ('Mary Williams', 'Broomfield'),
#  104: ('Debra Wood', 'Saint Paul'),
#  105: ('Mary Smith', 'Caguas'),
#  106: ('Lauren Freeman', 'Napa'),
#  107: ('Mary Weaver', 'Caguas'),
#  108: ('Joshua Smith', 'Bronx'),
#  109: ('Mary Thompson', 'Caguas'),
#  110: ('David Miranda', 'Beaverton'),
#  111: ('Frank Smith', 'Caguas'),
#  112: ('Mary Daniels', 'Middletown'),
#  113: ('Patricia Smith', 'Caguas'),
#  114: ('Alice Warner', 'Bellflower'),
#  115: ('Mary Smith', 'West Covina'),
#  116: ('John Hill', 'Caguas'),
#  117: ('Mary Smith', 'La Crosse'),
#  118: ('Katherine Olson', 'Ogden'),
#  119: ('Mary Rosario', 'Caguas'),
#  120: ('Nancy Smith', 'Bronx'),
#  121: ('Mary Yoder', 'Caguas'),
#  122: ('Karen Smith', 'Cincinnati'),
#  123: ('Mary Mann', 'Bend'),
#  124: ('Judy Smith', 'Caguas'),
#  125: ('Mary Gallagher', 'Oxnard'),
#  126: ('Austin Smith', 'Amarillo'),
#  127: ('Mary Martin', 'Caguas'),
#  128: ('Rose Lopez', 'Augusta'),
#  129: ('Crystal Smith', 'Caguas'),
#  130: ('Mary Holland', 'Aurora'),
#  131: ('Brenda Cline', 'Methuen'),
#  132: ('Eric Smith', 'Caguas'),
#  133: ('Mary Lopez', 'Brooklyn'),
#  134: ('Donna Gomez', 'Brooklyn'),
#  135: ('Mary Smith', 'Caguas'),
#  136: ('Ryan Griffin', 'Lynn'),
#  137: ('Jonathan Perkins', 'Broken Arrow'),
#  138: ('Mary Dawson', 'Caguas'),
#  139: ('Daniel Maxwell', 'San Diego'),
#  140: ('Amanda Smith', 'Caguas'),
#  141: ('Mary Mcmahon', 'Brooklyn'),
#  142: ('Heather Smith', 'Opa Locka'),
#  143: ('Mary Byrd', 'Caguas'),
#  144: ('David Smith', 'Bronx'),
#  145: ('Joan Walters', 'Dayton'),
#  146: ('Amber Mercado', 'Caguas'),
#  147: ('Mary Smith', 'Hanover'),
#  148: ('Stephanie Richards', 'Caguas'),
#  149: ('Shirley Mcclain', 'Colton'),
#  150: ('Mary Smith', 'Union'),
#  151: ('Lisa Shaw', 'Richmond'),
#  152: ('Mary Smith', 'Caguas'),
#  153: ('Andrew Marshall', 'Hollywood'),
#  154: ('Emily May', 'Brandon'),
#  155: ('Brittany Juarez', 'Caguas'),
#  156: ('Mary Smith', 'Los Angeles'),
#  157: ('Catherine Chan', 'Citrus Heights'),
#  158: ('Mary Smith', 'Caguas'),
#  159: ('John Love', 'Corona'),
#  160: ('Ashley Smith', 'Brooklyn'),
#  161: ('Mary Smith', 'Hialeah'),
#  162: ('John Garcia', 'Caguas'),
#  163: ('Austin Diaz', 'Rio Rancho'),
#  164: ('Mary Carlson', 'Caguas'),
#  165: ('Joseph Ewing', 'Antioch'),
#  166: ('Steven Smith', 'Florissant'),
#  167: ('Stephanie Rodriguez', 'Columbus'),
#  168: ('Eric Morris', 'Caguas'),
#  169: ('Debra Mccarthy', 'Bronx'),
#  170: ('Mary Smith', 'Broomfield'),
#  171: ('Evelyn Potter', 'Caguas'),
#  172: ('Lauren Rush', 'Chino'),
#  173: ('Jose Smith', 'Lombard'),
#  174: ('Mary Perez', 'Caguas'),
#  175: ('Ronald Guzman', 'Los Angeles'),
#  176: ('Amy Smith', 'Dundalk'),
#  177: ('Mary Melendez', 'Caguas'),
#  178: ('Keith Smith', 'Waukegan'),
#  179: ('Mary Rodgers', 'Los Angeles'),
#  180: ('Juan Smith', 'Caguas'),
#  181: ('Mary Jones', 'Irwin'),
#  182: ('James Ortiz', 'Caguas'),
#  183: ('Wayne Smith', 'Hayward'),
#  184: ('Mary Boyd', 'Lindenhurst'),
#  185: ('Deborah Smith', 'Louisville'),
#  186: ('Diane Jones', 'Caguas'),
#  187: ('Mildred Herrera', 'Antioch'),
#  188: ('Mary Smith', 'Los Angeles'),
#  189: ('Angela Peterson', 'San Marcos'),
#  190: ('Mary Hayes', 'Caguas'),
#  191: ('Victoria Smith', 'Portland'),
#  192: ('Mary Hall', 'Caguas'),
#  193: ('Melissa Flores', 'Gaithersburg'),
#  194: ('Mary Bates', 'Caguas'),
#  195: ('Richard Smith', 'Modesto'),
#  196: ('Thomas Watson', 'Dearborn'),
#  197: ('Ruth Smith', 'Caguas'),
#  198: ('Mary Joseph', 'Lancaster'),
#  199: ('Cynthia Horn', 'Caguas'),
#  200: ('Keith Smith', 'Lynn'),
#  201: ('Mary Grimes', 'Jacksonville'),
#  202: ('Sharon Smith', 'Caguas'),
#  203: ('Madison Blankenship', 'Phoenix'),
#  204: ('Mary Smith', 'Las Vegas'),
#  205: ('Ryan Garcia', 'Caguas'),
#  206: ('Mary West', 'Pompano Beach'),
#  207: ('Jose Powers', 'Caguas'),
#  208: ('Mary Smith', 'Bayamon'),
#  209: ('Thomas Moore', 'Fort Worth'),
#  210: ('Jonathan Burns', 'Caguas'),
#  211: ('Mary Smith', 'Lawrenceville'),
#  212: ('Roger Johnson', 'South Ozone Park'),
#  213: ('Mary Mclaughlin', 'Enfield'),
#  214: ('Lauren Booth', 'Caguas'),
#  215: ('Mary Smith', 'Flushing'),
#  216: ('Martha Davis', 'Visalia'),
#  217: ('Mary Hughes', 'Caguas'),
#  218: ('Charles Tyler', 'La Puente'),
#  219: ('Mary Harrell', 'Denver'),
#  220: ('Janet Smith', 'Salinas'),
#  221: ('Mary Cox', 'Columbus'),
#  222: ('Frank Ruiz', 'Carol Stream'),
#  223: ('Ralph Smith', 'Caguas'),
#  224: ('Mary Hernandez', 'Wheeling'),
#  225: ('Megan Watson', 'Caguas'),
#  226: ('Rose Sanders', 'Oxnard'),
#  227: ('Mary Smith', 'Tempe'),
#  228: ('Jessica Clark', 'Caguas'),
#  229: ('Mary Garrett', 'Jacksonville'),
#  230: ('Kimberly Smith', 'Caguas'),
#  231: ('Mary Conner', 'Wyoming'),
#  232: ('Gloria Bean', 'Caguas'),
#  233: ('Hannah Smith', 'Glendale'),
#  234: ('Mary Giles', 'Miami'),
#  235: ('David Smith', 'Piscataway'),
#  236: ('Ashley Clark', 'Caguas'),
#  237: ('Mary Smith', 'San Jose'),
#  238: ('Charles Turner', 'Caguas'),
#  239: ('Mary Simpson', 'Mcallen'),
#  240: ('David Smith', 'Caguas'),
#  241: ('Janet Carter', 'Hamilton'),
#  242: ('Mary Stein', 'Mililani'),
#  243: ('Deborah Smith', 'Caguas'),
#  244: ('Mary Hutchinson', 'Long Beach'),
#  245: ('Deborah Smith', 'Yonkers'),
#  246: ('Mary Wood', 'Oak Lawn'),
#  247: ('Angela Smith', 'Caguas'),
#  248: ('Christina Walsh', 'Houston'),
#  249: ('Mary Randolph', 'Portland'),
#  250: ('Julie Smith', 'Caguas'),
#  251: ('Kelly Adams', 'Saint Paul'),
#  252: ('Mary Frazier', 'Richardson'),
#  253: ('Nancy Smith', 'Caguas'),
#  254: ('Diana Hale', 'San Antonio'),
#  255: ('Mary Smith', 'Caguas'),
#  256: ('David Rodriguez', 'Chicago'),
#  257: ('Mary Harrison', 'Humacao'),
#  258: ('Aaron Kennedy', 'Philadelphia'),
#  259: ('Mary Bates', 'Caguas'),
#  260: ('Kenneth Smith', 'North Hollywood'),
#  261: ('Mary Parker', 'Cerritos'),
#  262: ('Mary Morgan', 'Chicago'),
#  263: ('Margaret Bradley', 'Caguas'),
#  264: ('Mary Smith', 'Goleta'),
#  265: ('Michelle Solis', 'Dubuque'),
#  266: ('Mary Knapp', 'Caguas'),
#  267: ('Richard Smith', 'Columbus'),
#  268: ('Mary Miller', 'Caguas'),
#  269: ('Jeffrey Simon', 'Chicago'),
#  270: ('Janet Smith', 'Caguas'),
#  271: ('Justin White', 'Fremont'),
#  272: ('Mary Long', 'Caguas'),
#  273: ('Benjamin Smith', 'Jamaica'),
#  274: ('Mary Moyer', 'San Antonio'),
#  275: ('Robert Smith', 'Caguas'),
#  276: ('Christina Wright', 'West Covina'),
#  277: ('Roger Hunt', 'Caguas'),
#  278: ('Mary Graves', 'Brooklyn'),
#  279: ('Anna Smith', 'Bayamon'),
#  280: ('Mary Ortiz', 'Caguas'),
#  281: ('Stephanie Smith', 'Juana Diaz'),
#  282: ('Zachary Pugh', 'Caguas'),
#  283: ('Mary Smith', 'Wilmington'),
#  284: ('John Harrington', 'Caguas'),
#  285: ('Shirley Smith', 'Lancaster'),
#  286: ('Mary Baker', 'Santa Cruz'),
#  287: ('Andrew Salazar', 'Caguas'),
#  288: ('Judith Smith', 'San Juan'),
#  289: ('Diana Richards', 'Morristown'),
#  290: ('Mary Garza', 'Caguas'),
#  291: ('John Smith', 'Bristol'),
#  292: ('Mary Estrada', 'Columbus'),
#  293: ('Christopher Prince', 'Caguas'),
#  294: ('Mary Smith', 'Newark'),
#  295: ('Julie Tanner', 'Caguas'),
#  296: ('Mary Mullen', 'Detroit'),
#  297: ('Catherine Smith', 'Caguas'),
#  298: ('Mary Logan', 'Chicago'),
#  299: ('Katherine Smith', 'Troy'),
#  300: ('Mary Key', 'Plano'),
#  301: ('Arthur Smith', 'Caguas'),
#  302: ('Mary Nguyen', 'Fullerton'),
#  303: ('Thomas Rowe', 'Caguas'),
#  304: ('Christopher Smith', 'New Haven'),
#  305: ('Mary Lawrence', 'Caguas'),
#  306: ('Alan Boyle', 'Phoenix'),
#  307: ('Mary Smith', 'Baltimore'),
#  308: ('Alan Berger', 'South Ozone Park'),
#  309: ('Phillip Smith', 'Caguas'),
#  310: ('Mary Fox', 'York'),
#  311: ('Michael Townsend', 'Austin'),
#  312: ('Jack Smith', 'Houston'),
#  313: ('Mary Stark', 'Caguas'),
#  314: ('Maria Smith', 'Milwaukee'),
#  315: ('Danielle Hampton', 'Modesto'),
#  316: ('Mary Smith', 'Caguas'),
#  317: ('Deborah Salazar', 'Wayne'),
#  318: ('Samantha Smith', 'Caguas'),
#  319: ('Arthur Brown', 'Chicago'),
#  320: ('Mary Brooks', 'Chicago'),
#  321: ('David Smith', 'Ann Arbor'),
#  322: ('Barbara Kemp', 'Caguas'),
#  323: ('Joshua Smith', 'New York'),
#  324: ('Jean Clay', 'Pico Rivera'),
#  325: ('Mary Smith', 'Washington'),
#  326: ('Shirley Stafford', 'Caguas'),
#  327: ('Mary Smith', 'Carrollton'),
#  328: ('William Morrison', 'Caguas'),
#  329: ('Samantha Higgins', 'Miami'),
#  330: ('Mary Smith', 'Caguas'),
#  331: ('Alexander Russell', 'Tempe'),
#  332: ('Mary Smith', 'Placentia'),
#  333: ('Elizabeth Ferguson', 'Caguas'),
#  334: ('Kathleen Oconnor', 'Tracy'),
#  335: ('Mary Smith', 'Caguas'),
#  336: ('Ruth Armstrong', 'New York'),
#  337: ('Mary Neal', 'New Haven'),
#  338: ('Ryan Smith', 'Caguas'),
#  339: ('Mary Greene', 'Long Beach'),
#  340: ('Theresa Wiggins', 'Denton'),
#  341: ('Mary Smith', 'Carlsbad'),
#  342: ('Jerry Jackson', 'Caguas'),
#  343: ('Douglas Joseph', 'San Antonio'),
#  344: ('Mary Smith', 'Caguas'),
#  345: ('John Howard', 'Chicago'),
#  346: ('Edward Stephens', 'Caguas'),
#  347: ('Bryan Marsh', 'Dallas'),
#  348: ('Mary Smith', 'Caguas'),
#  349: ('Aaron Berger', 'Florissant'),
#  350: ('Mary Smith', 'Caguas'),
#  351: ('John Singh', 'Stockton'),
#  352: ('Gregory Smith', 'Caguas'),
#  353: ('Mary Smith', 'San Antonio'),
#  354: ('Edward Peterson', 'Caguas'),
#  355: ('Katherine Barker', 'Carmichael'),
#  356: ('Roger Smith', 'Catonsville'),
#  357: ('Mary King', 'Caguas'),
#  358: ('Megan Lynch', 'San Antonio'),
#  359: ('Mary Pena', 'Caguas'),
#  360: ('Ashley Smith', 'Summerville'),
#  361: ('Alexander Shaw', 'Caguas'),
#  362: ('Mary Smith', 'Diamond Bar'),
#  363: ('Jennifer Obrien', 'Caguas'),
#  364: ('Jason Mcmahon', 'Tulare'),
#  365: ('Shirley Smith', 'Garden Grove'),
#  366: ('Larry Williamson', 'Caguas'),
#  367: ('Mary Smith', 'San Francisco'),
#  368: ('Pamela Flores', 'Caguas'),
#  369: ('Madison Sheppard', 'Chicago'),
#  370: ('Mary Smith', 'Caguas'),
#  371: ('Adam Marquez', 'San Antonio'),
#  372: ('Mary Smith', 'Caguas'),
#  373: ('George Sandoval', 'Union City'),
#  374: ('Mary Camacho', 'Mesa'),
#  375: ('Mark Smith', 'Dallas'),
#  376: ('Grace Sanchez', 'Caguas'),
#  377: ('Mary Smith', 'Lancaster'),
#  378: ('John Stewart', 'Roswell'),
#  379: ('David Briggs', 'Wyandotte'),
#  380: ('Linda Smith', 'Caguas'),
#  381: ('Katherine Moore', 'Fairfield'),
#  382: ('Mary Lane', 'Caguas'),
#  383: ('Evelyn Smith', 'Huntington Beach'),
#  384: ('Mildred Cunningham', 'Las Vegas'),
#  385: ('Mary Smith', 'Caguas'),
#  386: ('Janet Wallace', 'Richmond'),
#  387: ('Mary Levy', 'Caguas'),
#  388: ('Robert Smith', 'Los Angeles'),
#  389: ('Angela Sanford', 'Modesto'),
#  390: ('Mary Smith', 'Caguas'),
#  391: ('Gloria Greene', 'Saginaw'),
#  392: ('Beverly Hanson', 'Doylestown'),
#  393: ('Mary Chambers', 'Caguas'),
#  394: ('David Smith', 'Lakewood'),
#  395: ('Edward Castro', 'Revere'),
#  396: ('Deborah Smith', 'Richmond'),
#  397: ('Mary Delgado', 'Cumberland'),
#  398: ('Teresa Smith', 'Caguas'),
#  399: ('Mary Perez', 'Las Vegas'),
#  400: ('Matthew Vaughan', 'Caguas'),
#  401: ('Bobby Smith', 'Aurora'),
#  402: ('Mary Brooks', 'Caguas'),
#  403: ('Nancy Fox', 'Las Vegas'),
#  404: ('Mary Adkins', 'Caguas'),
#  405: ('Kathleen Smith', 'Fort Lauderdale'),
#  406: ('Grace Patel', 'Asheboro'),
#  407: ('Mary Fischer', 'Atlanta'),
#  408: ('Elizabeth Raymond', 'Caguas'),
#  409: ('Kevin Smith', 'Greensboro'),
#  410: ('Jack Moore', 'Caguas'),
#  411: ('Mary Smith', 'Washington'),
#  412: ('Cynthia Crawford', 'Caguas'),
#  413: ('Mary Gordon', 'Potomac'),
#  414: ('Pamela Smith', 'Caguas'),
#  415: ('Mary Allen', 'San Diego'),
#  416: ('Rachel Dunn', 'Caguas'),
#  417: ('Teresa Smith', 'New York'),
#  418: ('Mary Jackson', 'Gardena'),
#  419: ('James Smith', 'Caguas'),
#  420: ('Jose Wright', 'Round Rock'),
#  421: ('Mary Smith', 'San Ramon'),
#  422: ('Deborah Moore', 'Caguas'),
#  423: ('Mary Weber', 'Huntington Beach'),
#  424: ('Stephen Douglas', 'Carlisle'),
#  425: ('Mary Sexton', 'Caguas'),
#  426: ('Susan Smith', 'Endicott'),
#  427: ('Paul Brown', 'Caguas'),
#  428: ('Andrew Smith', 'Spring Valley'),
#  429: ('Mary Salazar', 'Caguas'),
#  430: ('Mary Smith', 'Porterville'),
#  431: ('Michael Vance', 'Columbus'),
#  432: ('Bruce Mcconnell', 'Caguas'),
#  433: ('Mary Smith', 'Las Vegas'),
#  434: ('Michael Torres', 'Caguas'),
#  435: ('Joan Barr', 'Chicago'),
#  436: ('Mary Smith', 'Tampa'),
#  437: ('Cynthia Benjamin', 'Caguas'),
#  438: ('Diane Smith', 'Carlsbad'),
#  439: ('Rose Delgado', 'Caguas'),
#  440: ('Mary Skinner', 'Brooklyn'),
#  441: ('Aaron Riddle', 'Brooklyn'),
#  442: ('Mary Smith', 'Allentown'),
#  443: ('Barbara Robinson', 'Caguas'),
#  444: ('Walter Lambert', 'Sunnyvale'),
#  445: ('Mary Smith', 'Fort Washington'),
#  446: ('Scott Harris', 'Mission Viejo'),
#  447: ('Mary Nelson', 'Caguas'),
#  448: ('Hannah Joseph', 'Modesto'),
#  449: ('Mary Smith', 'Columbus'),
#  450: ('Kathryn Carter', 'Caguas'),
#  451: ('Mary Baldwin', 'Asheboro'),
#  452: ('Carl Smith', 'Caguas'),
#  453: ('Mary Glenn', 'Lancaster'),
#  454: ('Robert Fitzpatrick', 'Caguas'),
#  455: ('Jeffrey Smith', 'Colorado Springs'),
#  456: ('Douglas Turner', 'Caguas'),
#  457: ('Mary Smith', 'Brooklyn'),
#  458: ('Charles Spencer', 'San Francisco'),
#  459: ('Sean Smith', 'Sanford'),
#  460: ('Vincent Willis', 'Milford'),
#  461: ('Mary Smith', 'Caguas'),
#  462: ('Sean Skinner', 'Newark'),
#  463: ('Harry Smith', 'Caguas'),
#  464: ('Mary Mcintyre', 'Morrisville'),
#  465: ('Shawn Smith', 'Caguas'),
#  466: ('Mary Savage', 'Bronx'),
#  467: ('James Smith', 'Modesto'),
#  468: ('Mary Stone', 'Caguas'),
#  469: ('Randy Smith', 'South San Francisco'),
#  470: ('Mary Cannon', 'Far Rockaway'),
#  471: ('Helen Smith', 'Caguas'),
#  472: ('Mary Schultz', 'Bellflower'),
#  473: ('Jason Smith', 'Elmhurst'),
#  474: ('Mary Patton', 'Philadelphia'),
#  475: ('Brittany Gibbs', 'Caguas'),
#  476: ('Mary Carey', 'Eugene'),
#  477: ('Dylan Smith', 'Caguas'),
#  478: ('Mary Porter', 'Plainfield'),
#  479: ('Christopher Curtis', 'Caguas'),
#  480: ('Mary Smith', 'Austin'),
#  481: ('Ann Jackson', 'Los Angeles'),
#  482: ('Megan Moreno', 'Caguas'),
#  483: ('Mary Smith', 'Granada Hills'),
#  484: ('Shirley Richardson', 'Hyattsville'),
#  485: ('Mary George', 'Caguas'),
#  486: ('John Smith', 'Lancaster'),
#  487: ('Kenneth Brown', 'Caguas'),
#  488: ('Mary Dougherty', 'San Francisco'),
#  489: ('William Smith', 'Portland'),
#  490: ('Sandra Brown', 'Caguas'),
#  491: ('Debra Smith', 'Henderson'),
#  492: ('Mary Mckinney', 'Bayamon'),
#  493: ('Joseph Smith', 'Caguas'),
#  494: ('Mary Stanton', 'Greeley'),
#  495: ('Marilyn Smith', 'Caguas'),
#  496: ('Mary Allen', 'Revere'),
#  497: ('Amanda Odonnell', 'Caguas'),
#  498: ('Kyle Smith', 'Chicago'),
#  499: ('Mary York', 'San Diego'),
#  500: ('Nicholas Smith', 'Michigan City'),
#  501: ('Mary Harvey', 'Caguas'),
#  502: ('Jennifer May', 'South Richmond Hill'),
#  503: ('Rachel Smith', 'Caguas'),
#  504: ('Cheryl Livingston', 'Orange Park'),
#  505: ('Mary Smith', 'Scottsdale'),
#  506: ('Richard Holloway', 'Caguas'),
#  507: ('Steven Smith', 'Simi Valley'),
#  508: ('Ronald Medina', 'Rancho Cordova'),
#  509: ('Mary Smith', 'Caguas'),
#  510: ('Joseph Holt', 'Hialeah'),
#  511: ('Doris Smith', 'Caguas'),
#  512: ('Mary Harris', 'Fremont'),
#  513: ('Tyler Smith', 'Caguas'),
#  514: ('Mary Johnson', 'La Habra'),
#  515: ('Helen Poole', 'Stockbridge'),
#  516: ('Mary Smith', 'Caguas'),
#  517: ('John Russell', 'Brooklyn'),
#  518: ('Elizabeth Smith', 'Cerritos'),
#  519: ('Hannah Ruiz', 'Ogden'),
#  520: ('Mary Reid', 'Caguas'),
#  521: ('James Vaughn', 'Portland'),
#  522: ('William Smith', 'Caguas'),
#  523: ('Christopher Johnson', 'Mission Viejo'),
#  524: ('Catherine Cox', 'New Bedford'),
#  525: ('Mary Munoz', 'Caguas'),
#  526: ('Kimberly Barrett', 'Brownsville'),
#  527: ('Mary Gregory', 'Taunton'),
#  528: ('Susan Smith', 'Caguas'),
#  529: ('Kathy Jacobson', 'Chicago'),
#  530: ('Mary Smith', 'Newark'),
#  531: ('Paul Burns', 'Caguas'),
#  532: ('Mark Smith', 'Sugar Land'),
#  533: ('Olivia Edwards', 'Caguas'),
#  534: ('Mary Morris', 'Baldwin Park'),
#  535: ('Patricia Hunt', 'Bronx'),
#  536: ('Elizabeth Smith', 'Caguas'),
#  537: ('Mary Cochran', 'Costa Mesa'),
#  538: ('Joshua Livingston', 'Wilmington'),
#  539: ('Marilyn Smith', 'Ventura'),
#  540: ('Mary Tran', 'Caguas'),
#  541: ('Amanda Davidson', 'Lynwood'),
#  542: ('Mary Smith', 'Caguas'),
#  543: ('Alice Lucero', 'Greenville'),
#  544: ('Mary Smith', 'Caguas'),
#  545: ('Joe Andrade', 'El Cajon'),
#  546: ('Mary Smith', 'Clearfield'),
#  547: ('Kathleen Contreras', 'Hyattsville'),
#  548: ('Ryan Horton', 'Caguas'),
#  549: ('Mary Smith', 'Sugar Land'),
#  550: ('Betty Chavez', 'Lancaster'),
#  551: ('Doris Weaver', 'Caguas'),
#  552: ('Mary Harper', 'Los Angeles'),
#  553: ('Eugene Smith', 'Fremont'),
#  554: ('Mary Branch', 'Caguas'),
#  555: ('Mildred Smith', 'Compton'),
#  556: ('Nathan Mcbride', 'Caguas'),
#  557: ('Mary Smith', 'Waipahu'),
#  558: ('Michael Mclaughlin', 'Carlisle'),
#  559: ('Paul Melton', 'Caguas'),
#  560: ('Emma Smith', 'Richmond'),
#  561: ('Ralph Griffith', 'Caguas'),
#  562: ('Mary Smith', 'Tracy'),
#  563: ('Harry Contreras', 'Los Angeles'),
#  564: ('Mary Mccann', 'Caguas'),
#  565: ('Christian Smith', 'San Francisco'),
#  566: ('Mary Mcmahon', 'Dayton'),
#  567: ('Donna Smith', 'Las Vegas'),
#  568: ('Sean Vaughn', 'Caguas'),
#  569: ('Mary Frye', 'Meridian'),
#  570: ('Julia Whitney', 'Buffalo'),
#  571: ('Mary Smith', 'Caguas'),
#  572: ('Bobby Rowe', 'Spring Valley'),
#  573: ('Mary Smith', 'Washington'),
#  574: ('Randy Bond', 'Joliet'),
#  575: ('Mary Smith', 'Rancho Cucamonga'),
#  576: ('Arthur Fisher', 'Houston'),
#  577: ('Mary Smith', 'Caguas'),
#  578: ('Dylan Knapp', 'Kaneohe'),
#  579: ('Mary Smith', 'New Orleans'),
#  580: ('Kimberly Lee', 'Caguas'),
#  581: ('Mary Lara', 'West New York'),
#  582: ('Kenneth Smith', 'Garland'),
#  583: ('Mary Wright', 'San Marcos'),
#  584: ('Tyler Berger', 'Caguas'),
#  585: ('Mary Smith', 'New York'),
#  586: ('Patricia Jefferson', 'San Marcos'),
#  587: ('Patrick Smith', 'Ogden'),
#  588: ('Roy Clark', 'Caguas'),
#  589: ('Mary Reynolds', 'Oxnard'),
#  590: ('Paul Black', 'Meridian'),
#  591: ('Rose Smith', 'Caguas'),
#  592: ('Mary Huynh', 'Detroit'),
#  593: ('Juan Ashley', 'Caguas'),
#  594: ('Mary Cowan', 'Lynnwood'),
#  595: ('Brian Smith', 'Caguas'),
#  596: ('Mary Serrano', 'Pompano Beach'),
#  597: ('Samantha Smith', 'Caguas'),
#  598: ('Mary Levy', 'Paramount'),
#  599: ('Doris Smith', 'Caguas'),
#  600: ('Mary Jenkins', 'Bend'),
#  601: ('Patricia Smith', 'Caguas'),
#  602: ('Rebecca Huff', 'Brooklyn'),
#  603: ('Austin Smith', 'Fresno'),
#  604: ('Mary Chapman', 'Caguas'),
#  605: ('Donald Lucero', 'Brooklyn'),
#  606: ('Mary Smith', 'Newark'),
#  607: ('Richard Reed', 'Caguas'),
#  608: ('Carol Smith', 'Fairfield'),
#  609: ('Kevin Cantu', 'Caguas'),
#  610: ('Mary Smith', 'New York'),
#  611: ('Lisa Cross', 'El Cajon'),
#  612: ('Mary Cochran', 'Caguas'),
#  613: ('Emma Smith', 'South Ozone Park'),
#  614: ('Jack Benson', 'Caguas'),
#  615: ('Mary Smith', 'El Paso'),
#  616: ('Nancy Mcclure', 'Smyrna'),
#  617: ('Stephanie Smith', 'Caguas'),
#  618: ('Mary Davis', 'Jackson Heights'),
#  619: ('Matthew Sutton', 'Houston'),
#  620: ('Roger Smith', 'Caguas'),
#  621: ('Mary Shannon', 'Anaheim'),
#  622: ('Karen Davies', 'Caguas'),
#  623: ('Judith Smith', 'Tempe'),
#  624: ('Mary Ruiz', 'Oceanside'),
#  625: ('Terry Smith', 'Caguas'),
#  626: ('Mary Weeks', 'Dallas'),
#  627: ('Robert Smith', 'Honolulu'),
#  628: ('Margaret Olson', 'Caguas'),
#  629: ('Matthew Huffman', 'Van Nuys'),
#  630: ('Jacob Smith', 'Caguas'),
#  631: ('Mary Colon', 'Brooklyn'),
#  632: ('George Smith', 'Grand Prairie'),
#  633: ('Mary Campbell', 'Caguas'),
#  634: ('Jack Edwards', 'Riverside'),
#  635: ('Mary Smith', 'Caguas'),
#  636: ('Albert Merritt', 'Long Beach'),
#  637: ('Mary Smith', 'Caguas'),
#  638: ('Michael Johnson', 'Bridgeton'),
#  639: ('Elizabeth Pittman', 'Caguas'),
#  640: ('Jean Smith', 'New Castle'),
#  641: ('Mary Hamilton', 'Plainfield'),
#  642: ('Timothy Vasquez', 'Caguas'),
#  643: ('Tammy Boyd', 'New Orleans'),
#  644: ('Mary Smith', 'Caguas'),
#  645: ('Mary Conner', 'Cupertino'),
#  646: ('Tammy Smith', 'Ann Arbor'),
#  647: ('Mary Rios', 'Caguas'),
#  648: ('Ashley Buck', 'Arecibo'),
#  649: ('Mary Smith', 'Stockton'),
#  650: ('Austin Sexton', 'Caguas'),
#  651: ('Mary Smith', 'Santa Fe'),
#  652: ('Joseph Thompson', 'Alpharetta'),
#  653: ('Jason Haas', 'Caguas'),
#  654: ('Mary Smith', 'Orange Park'),
#  655: ('Joseph Dougherty', 'Caguas'),
#  656: ('Julie Smith', 'Pomona'),
#  657: ('Mary Bowers', 'Caguas'),
#  658: ('Peter Farley', 'Irwin'),
#  659: ('Mary Smith', 'Greenville'),
#  660: ('Shirley Baker', 'Caguas'),
#  661: ('Mary Montgomery', 'Detroit'),
#  662: ('Michelle Moss', 'Caguas'),
#  663: ('Mary Smith', 'Pacoima'),
#  664: ('Bobby Jimenez', 'Holland'),
#  665: ('Mary Smith', 'Caguas'),
#  666: ('Amanda Simpson', 'Orange Park'),
#  667: ('Mary Smith', 'Caguas'),
#  668: ('Phillip Lewis', 'Peoria'),
#  669: ('Mary Valentine', 'San Jose'),
#  670: ('Mary Smith', 'Caguas'),
#  671: ('Anthony Reyes', 'Tucson'),
#  672: ('Mary Marsh', 'Caguas'),
#  673: ('James Smith', 'Chula Vista'),
#  674: ('Jose Reynolds', 'Morrisville'),
#  675: ('Mary Mata', 'Greensboro'),
#  676: ('Robert Smith', 'Caguas'),
#  677: ('Justin Nguyen', 'Waukegan'),
#  678: ('Cheryl Massey', 'Amarillo'),
#  679: ('Grace Smith', 'Caguas'),
#  680: ('Brittany Brooks', 'Strongsville'),
#  681: ('Mary Sutton', 'Caguas'),
#  682: ('Emma Smith', 'Salinas'),
#  683: ('Mary Delgado', 'Harlingen'),
#  684: ('Christopher Terrell', 'Highland Park'),
#  685: ('Crystal Smith', 'Caguas'),
#  686: ('Mary Myers', 'North Hollywood'),
#  687: ('Ronald Harrison', 'Garden Grove'),
#  688: ('Kathy Gross', 'Houston'),
#  689: ('Mary Smith', 'Caguas'),
#  690: ('Michael Banks', 'Salt Lake City'),
#  691: ('Mary Terrell', 'Stafford'),
#  692: ('Ann Smith', 'Phoenix'),
#  693: ('Mary King', 'Caguas'),
#  694: ('Barbara Marshall', 'Elmhurst'),
#  695: ('Sara Smith', 'Roswell'),
#  696: ('Mary Romero', 'Caguas'),
#  697: ('Harold Pratt', 'Washington'),
#  698: ('Mary Smith', 'Caguas'),
#  699: ('Raymond Richards', 'Houston'),
#  700: ('Mary Cummings', 'Chula Vista'),
#  701: ('Joseph Coffey', 'Hollister'),
#  702: ('Cynthia Smith', 'Bend'),
#  703: ('Joan Kelly', 'Miami'),
#  704: ('Mary Mccullough', 'Caguas'),
#  705: ('Timothy Smith', 'Atlanta'),
#  706: ('Olivia Ramirez', 'Brighton'),
#  707: ('Shawn Ortiz', 'Caguas'),
#  708: ('Mary Rice', 'Phoenix'),
#  709: ('Matthew Klein', 'Caguas'),
#  710: ('Mary Smith', 'Seattle'),
#  711: ('Barbara Mccarthy', 'Caguas'),
#  712: ('Mary Ayala', 'Vega Baja'),
#  713: ('James Beasley', 'Moreno Valley'),
#  714: ('Mark Beltran', 'Caguas'),
#  715: ('Mary Smith', 'Dubuque'),
#  716: ('Louis Bishop', 'Caguas'),
#  717: ('Mary Camacho', 'Albuquerque'),
#  718: ('Alexander Smith', 'Caguas'),
#  719: ('Mary Hughes', 'Tucson'),
#  720: ('Thomas Smith', 'Caguas'),
#  721: ('Catherine Thompson', 'Lancaster'),
#  722: ('Diane Schmitt', 'Caguas'),
#  723: ('Mary Smith', 'Richmond'),
#  724: ('Lawrence Mclaughlin', 'Caguas'),
#  725: ('Mary Smith', 'San Bernardino'),
#  726: ('Barbara Myers', 'Mililani'),
#  727: ('Mary Smith', 'Caguas'),
#  728: ('Anthony Rosario', 'Philadelphia'),
#  729: ('Andrew Smith', 'Caguas'),
#  730: ('Mary Drake', 'Bronx'),
#  731: ('Robert Smith', 'Lilburn'),
#  732: ('David Cobb', 'Caguas'),
#  733: ('Alice Sellers', 'Amarillo'),
#  734: ('Mary Smith', 'Caguas'),
#  735: ('Charles Ross', 'Saint Peters'),
#  736: ('Carol Gill', 'Longview'),
#  737: ('Lawrence Smith', 'Pomona'),
#  738: ('Mary Wood', 'Caguas'),
#  739: ('Daniel Golden', 'Los Angeles'),
#  740: ('Brandon Smith', 'Caguas'),
#  741: ('Johnny Medina', 'Brooklyn'),
#  742: ('Mary Park', 'Santa Maria'),
#  743: ('Cynthia Smith', 'Caguas'),
#  744: ('Gary Hodges', 'North Hollywood'),
#  745: ('Mary Smith', 'Caguas'),
#  746: ('Christopher Bush', 'Santa Ana'),
#  747: ('Mary Dyer', 'Paramount'),
#  748: ('Olivia Smith', 'Del Rio'),
#  749: ('Jesse Matthews', 'Caguas'),
#  750: ('Mary Smith', 'Chicago'),
#  751: ('Benjamin Juarez', 'Los Angeles'),
#  752: ('Mary Smith', 'Caguas'),
#  753: ('Sandra Stafford', 'New York'),
#  754: ('Jacqueline Smith', 'Caguas'),
#  755: ('Mary Mayo', 'Tucson'),
#  756: ('Robert Smith', 'Peabody'),
#  757: ('Jane Smith', 'Tempe'),
#  758: ('Mary Sanders', 'Caguas'),
#  759: ('Donna Smith', 'Lawton'),
#  760: ('Emma Rivas', 'Caguas'),
#  761: ('Sara Rowland', 'Sunnyvale'),
#  762: ('Mary Smith', 'Caguas'),
#  763: ('Michael Carpenter', 'Chicago'),
#  764: ('David Smith', 'Mililani'),
#  765: ('Diane Miller', 'Caguas'),
#  766: ('Mary Smith', 'Austin'),
#  767: ('Christine Horne', 'Caguas'),
#  768: ('Mary Smith', 'Indio'),
#  769: ('Lori Bailey', 'Spokane'),
#  770: ('Mary Dudley', 'Caguas'),
#  771: ('Patricia Smith', 'Pawtucket'),
#  772: ('Mary Watson', 'Caguas'),
#  773: ('Dylan Horton', 'Saint Paul'),
#  774: ('Mary Smith', 'Caguas'),
#  775: ('Donna Bautista', 'College Station'),
#  776: ('Keith Smith', 'Caguas'),
#  777: ('Mary Mullins', 'Los Angeles'),
#  778: ('John Buckley', 'Caguas'),
#  779: ('Kenneth Smith', 'New Haven'),
#  780: ('Heather Brennan', 'Caguas'),
#  781: ('Samuel Smith', 'Miami'),
#  782: ('Mary Joseph', 'Dallas'),
#  783: ('Cheryl Kent', 'Broomfield'),
#  784: ('Mary Smith', 'Los Angeles'),
#  785: ('Lauren Gonzalez', 'Caguas'),
#  786: ('Mary Green', 'Chicago'),
#  787: ('Amanda Ochoa', 'Piscataway'),
#  788: ('Patrick Smith', 'Caguas'),
#  789: ('Mary Martinez', 'San Diego'),
#  790: ('Martha Robinson', 'Honolulu'),
#  791: ('Mary Smith', 'Canton'),
#  792: ('Evelyn Jordan', 'Caguas'),
#  793: ('Mary Smith', 'San Antonio'),
#  794: ('Lawrence Bennett', 'Orlando'),
#  795: ('Mary Knox', 'Caguas'),
#  796: ('Donna Smith', 'Tallahassee'),
#  797: ('Carl Rodriguez', 'Caguas'),
#  798: ('Mary Espinoza', 'Chandler'),
#  799: ('Danielle Smith', 'Pompano Beach'),
#  800: ('Mary Smith', 'Caguas'),
#  801: ('Elizabeth Parker', 'Vista'),
#  802: ('Mary Rogers', 'Caguas'),
#  803: ('James Hartman', 'Miami'),
#  804: ('William Dudley', 'Caguas'),
#  805: ('Stephen Smith', 'Ypsilanti'),
#  806: ('Mary Wells', 'Caguas'),
#  807: ('Kevin Benjamin', 'Elk Grove'),
#  808: ('Mary Smith', 'San Benito'),
#  809: ('Hannah Avila', 'Caguas'),
#  810: ('Mary Smith', 'Las Vegas'),
#  811: ('Jean Mcintyre', 'Caguas'),
#  812: ('Mary Smith', 'Bronx'),
#  813: ('Jack Johnson', 'San Francisco'),
#  814: ('Mary Stark', 'Chicago'),
#  815: ('Johnny Smith', 'Caguas'),
#  816: ('Mary Hopkins', 'Miami'),
#  817: ('Jack Smith', 'Stockbridge'),
#  818: ('Mary Kennedy', 'San Diego'),
#  819: ('Roy Smith', 'Carolina'),
#  820: ('Mary Brown', 'Caguas'),
#  821: ('Daniel Clayton', 'Piscataway'),
#  822: ('Rebecca Smith', 'Rowland Heights'),
#  823: ('Catherine Small', 'Caguas'),
#  824: ('Mary Smith', 'Hagerstown'),
#  825: ('George Ross', 'Aurora'),
#  826: ('Mary Delacruz', 'Caguas'),
#  827: ('Tyler Smith', 'New York'),
#  828: ('Johnny Herrera', 'Caguas'),
#  829: ('Mary Smith', 'West Orange'),
#  830: ('William Herrera', 'Caguas'),
#  831: ('Daniel Smith', 'Crystal Lake'),
#  832: ('Mary Carroll', 'Caguas'),
#  833: ('Alexander Smith', 'Dubuque'),
#  834: ('Mary Stafford', 'Caguas'),
#  835: ('Gloria Smith', 'Santee'),
#  836: ('Mary Anderson', 'Dearborn'),
#  837: ('Andrew May', 'Caguas'),
#  838: ('Mary Smith', 'Tinley Park'),
#  839: ('Lisa Walker', 'Caguas'),
#  840: ('Mary Kidd', 'Sylmar'),
#  841: ('David Smith', 'Bronx'),
#  842: ('Patrick Murphy', 'New Haven'),
#  843: ('Mary Smith', 'Caguas'),
#  844: ('Jessica Price', 'Las Vegas'),
#  845: ('Catherine Smith', 'Carlsbad'),
#  846: ('Mary Powell', 'Caguas'),
#  847: ('Jerry Ferguson', 'San Diego'),
#  848: ('Mary Smith', 'Los Angeles'),
#  849: ('Sandra Barker', 'Caguas'),
#  850: ('Sean Smith', 'North Bergen'),
#  851: ('Mary Snyder', 'El Centro'),
#  852: ('Deborah Smith', 'Caguas'),
#  853: ('Mary Larson', 'Rowland Heights'),
#  854: ('Daniel Smith', 'Del Rio'),
#  855: ('Mary Davis', 'Caguas'),
#  856: ('Dennis Ramos', 'Fountain Valley'),
#  857: ('Mary Duran', 'Houston'),
#  858: ('Robert Smith', 'Caguas'),
#  859: ('Dorothy Hawkins', 'Greensburg'),
#  860: ('Terry Smith', 'Houston'),
#  861: ('Mary Gentry', 'Caguas'),
#  862: ('Richard Smith', 'San Antonio'),
#  863: ('Katherine Scott', 'Caguas'),
#  864: ('Raymond Kidd', 'Plano'),
#  865: ('Mary Smith', 'Caguas'),
#  866: ('James Davies', 'Quincy'),
#  867: ('Catherine Smith', 'Caguas'),
#  868: ('Mary Contreras', 'Irvington'),
#  869: ('Mary Smith', 'Ontario'),
#  870: ('Linda Delacruz', 'Caguas'),
#  871: ('Deborah Smith', 'Amarillo'),
#  872: ('Keith Barnes', 'Caguas'),
#  873: ('Mary Smith', 'Bay Shore'),
#  874: ('Shirley Alexander', 'Phoenix'),
#  875: ('Mary Brady', 'Caguas'),
#  876: ('Andrea Smith', 'Aurora'),
#  877: ('Gerald Adkins', 'Caguas'),
#  878: ('Mary Smith', 'West Covina'),
#  879: ('Joseph Thomas', 'Caguas'),
#  880: ('Mary Guzman', 'Marietta'),
#  881: ('Marilyn Orozco', 'Memphis'),
#  882: ('Mary Smith', 'Caguas'),
#  883: ('Margaret Ayala', 'Santa Clara'),
#  884: ('Mary Smith', 'Florissant'),
#  885: ('Donna Powell', 'Chesapeake'),
#  886: ('Mary Henderson', 'Caguas'),
#  887: ('Brian Landry', 'Reseda'),
#  888: ('Mary Smith', 'Los Angeles'),
#  889: ('James Sanders', 'San Marcos'),
#  890: ('Danielle Smith', 'Caguas'),
#  891: ('Mary Manning', 'Beaverton'),
#  892: ('Laura Smith', 'Mesquite'),
#  893: ('Dennis Mcbride', 'Ogden'),
#  894: ('Mary Sawyer', 'Caguas'),
#  895: ('Dorothy Villegas', 'Chicago'),
#  896: ('Mary Smith', 'Caguas'),
#  897: ('Anthony Schultz', 'Aurora'),
#  898: ('Cheryl Smith', 'Tampa'),
#  899: ('Mary Webster', 'Caguas'),
#  900: ('George Smith', 'Holland'),
#  901: ('Mary Gillespie', 'Caguas'),
#  902: ('Virginia Smith', 'Dearborn'),
#  903: ('Mary Ramirez', 'San Jose'),
#  904: ('Elizabeth Gonzales', 'Caguas'),
#  905: ('Virginia Smith', 'Walnut'),
#  906: ('Mary Savage', 'Caguas'),
#  907: ('Samantha Kline', 'North Las Vegas'),
#  908: ('Mary Smith', 'Caguas'),
#  909: ('Laura Ford', 'Kent'),
#  910: ('Mary Smith', 'Hilliard'),
#  911: ('Peter Garcia', 'Caguas'),
#  912: ('Mary Roy', 'Las Vegas'),
#  913: ('William Smith', 'Caguas'),
#  914: ('Jacob Martinez', 'Bronx'),
#  915: ('Sean Burton', 'Broken Arrow'),
#  916: ('Mary Smith', 'Caguas'),
#  917: ('Andrew Glenn', 'Palatine'),
#  918: ('Nathan Smith', 'Caguas'),
#  919: ('Mary Mitchell', 'Cypress'),
#  920: ('Megan Schmidt', 'New Braunfels'),
#  921: ('Mary Smith', 'Caguas'),
#  922: ('Stephanie Willis', 'Lancaster'),
#  923: ('Mary Smith', 'Norfolk'),
#  924: ('Willie Klein', 'Eugene'),
#  925: ('Mary Smith', 'Caguas'),
#  926: ('Ashley Browning', 'Wilkes Barre'),
#  927: ('Diana Smith', 'Caguas'),
#  928: ('Mary Wilson', 'Brooklyn'),
#  929: ('Alan Smith', 'Pompano Beach'),
#  930: ('Mary Franco', 'Mission Viejo'),
#  931: ('Robert Smith', 'Caguas'),
#  932: ('Virginia Sandoval', 'Middletown'),
#  933: ('Mary Smith', 'Bridgeton'),
#  934: ('James Santiago', 'Caguas'),
#  935: ('Melissa Sharp', 'New York'),
#  936: ('Mary Smith', 'Winnetka'),
#  937: ('Daniel Cole', 'Caguas'),
#  938: ('Cheryl Smith', 'Madison'),
#  939: ('Mary Todd', 'Caguas'),
#  940: ('Steven Smith', 'El Paso'),
#  941: ('Jeremy Rowe', 'Modesto'),
#  942: ('Mary Smith', 'Caguas'),
#  943: ('John Cummings', 'Tucson'),
#  944: ('Stephanie Smith', 'Wyoming'),
#  945: ('Carl Reynolds', 'Indio'),
#  946: ('Mary Smith', 'La Mesa'),
#  947: ('Mary Henry', 'Caguas'),
#  948: ('Michelle Smith', 'Lawrence'),
#  949: ('Mary Sawyer', 'Caguas'),
#  950: ('Jordan Smith', 'Las Vegas'),
#  951: ('Mary Young', 'Caguas'),
#  952: ('Jack Smith', 'Hesperia'),
#  953: ('Mary Mills', 'Philadelphia'),
#  954: ('Brandon Fitzgerald', 'Richmond'),
#  955: ('Mary Marks', 'Caguas'),
#  956: ('Karen Smith', 'Bronx'),
#  957: ('Eric Jones', 'Stockton'),
#  958: ('Peter Acosta', 'Caguas'),
#  959: ('Mary Smith', 'Tempe'),
#  960: ('Michael Mcdonald', 'New Bedford'),
#  961: ('David Smith', 'Caguas'),
#  962: ('Mary Bowers', 'Saint Peters'),
#  963: ('Eugene Smith', 'Toms River'),
#  964: ('Mary Frazier', 'New York'),
#  965: ('Sean Smith', 'Jonesboro'),
#  966: ('Mary Buchanan', 'Los Angeles'),
#  967: ('Madison Smith', 'Caguas'),
#  968: ('Mary Larson', 'Cleveland'),
#  969: ('Rose Smith', 'Bakersfield'),
#  970: ('Mary Alvarez', 'Caguas'),
#  971: ('Jacqueline Krueger', 'Douglasville'),
#  972: ('Mary Smith', 'Caguas'),
#  973: ('Linda Hart', 'Cleveland'),
#  974: ('George Smith', 'Fresno'),
#  975: ('Mary Willis', 'Saginaw'),
#  976: ('Shirley Henson', 'Caguas'),
#  977: ('Virginia Smith', 'Garden Grove'),
#  978: ('Nicholas Peters', 'Caguas'),
#  979: ('Mary Smith', 'Austin'),
#  980: ('James Harper', 'San Jose'),
#  981: ('Christine Schwartz', 'Caguas'),
#  982: ('Mary Robbins', 'New Albany'),
#  983: ('Michael Richmond', 'Caguas'),
#  984: ('Amy Smith', 'Chicago'),
#  985: ('Mary Martinez', 'Richmond'),
#  986: ('Catherine Hawkins', 'Caguas'),
#  987: ('Cheryl Smith', 'Albuquerque'),
#  988: ('Mary Brady', 'Pittsfield'),
#  989: ('Helen Smith', 'Caguas'),
#  990: ('Mary Ellison', 'Merced'),
#  991: ('John Smith', 'Caguas'),
#  992: ('Randy Brown', 'New York'),
#  993: ('Mary Davis', 'Fairfield'),
#  994: ('Lisa Massey', 'Caguas'),
#  995: ('Helen Hinton', 'Richmond'),
#  996: ('Amanda Smith', 'Austin'),
#  997: ('Mary Price', 'Caguas'),
#  998: ('Steven Salinas', 'Anaheim'),
#  999: ('Mary Stephenson', 'Saint Paul'),
#  1000: ('James Smith', 'Freeport'),
#  ...}

# %% [markdown]
# ## --> Reading order_items

# %%
order_item_rdd = sc.textFile("data/retail_db/order_items.csv")

# %%
order_item_rdd = order_item_rdd.filter(lambda x: "orderItemOrderId" not in x)

# %%
order_item_rdd.take(5)
# Out:
# ['1,1,957,1,299.98,299.98',
#  '2,2,1073,1,199.99,199.99',
#  '3,2,502,5,250.0,50.0',
#  '4,2,403,1,129.99,129.99',
#  '5,4,897,2,49.98,24.99']

# %% [markdown]
# ## Creating Pair RDD from Order_Items table

# %%
def make_orderItems_pairRdd(line):
    orderItems_productId = int(line.split(",")[2])
    orderItems_subTotal = float(line.split(",")[4])
    
    return (orderItems_productId, orderItems_subTotal)

# %%
orderItem_pairRdd = order_item_rdd.map(make_orderItems_pairRdd)

# %%
print("(orderItems_ProductId, orderItems_subTotal)")
orderItem_pairRdd.take(5)
# Out:
# (orderItems_ProductId, orderItems_subTotal)
# [(957, 299.98), (1073, 199.99), (502, 250.0), (403, 129.99), (897, 49.98)]

# %% [markdown]
# ### [Example]: Total Subtotal by using multiple map()

# %%
print("(orderItems_ProductId, orderItems_subTotal)")
orderItem_pairRdd.reduceByKey(lambda x,y: (x+y))\
.map(lambda x: (x[1],x[0]))\
.sortByKey(False)\
.map(lambda x: (x[1],x[0]))\
.take(10)
# Out:
# (orderItems_ProductId, orderItems_subTotal)
# [(1004, 6929653.499999708),
#  (365, 4421143.019999639),
#  (957, 4118425.419999785),
#  (191, 3667633.1999997487),
#  (502, 3147800.0),
#  (1073, 3099844.999999871),
#  (403, 2891757.5399998166),
#  (1014, 2888993.9399996493),
#  (627, 1269082.649999932),
#  (565, 67830.0)]

# %% [markdown]
# ### [Example]: Total SubTotal by using sortBy(lambda)

# %%
print("(ProductId, Total_subTotal)")
orderItem_pairRdd.reduceByKey(lambda x,y: (x+y))\
.sortBy(lambda x: x[1], ascending = False)\
.take(10)
# Out:
# (ProductId, Total_subTotal)
# [(1004, 6929653.499999708),
#  (365, 4421143.019999639),
#  (957, 4118425.419999785),
#  (191, 3667633.1999997487),
#  (502, 3147800.0),
#  (1073, 3099844.999999871),
#  (403, 2891757.5399998166),
#  (1014, 2888993.9399996493),
#  (627, 1269082.649999932),
#  (565, 67830.0)]

# %%
sorted_orders = orderItem_pairRdd.reduceByKey(lambda x,y: (x+y)).sortBy(lambda x: x[1], ascending = False)

# %%
sorted_orders.take(10)
# Out:
# [(1004, 6929653.499999708),
#  (365, 4421143.019999639),
#  (957, 4118425.419999785),
#  (191, 3667633.1999997487),
#  (502, 3147800.0),
#  (1073, 3099844.999999871),
#  (403, 2891757.5399998166),
#  (1014, 2888993.9399996493),
#  (627, 1269082.649999932),
#  (565, 67830.0)]

# %% [markdown]
# ### [Example]: Best-Seller (Most sold) 10 products

# %%
sorted_orders_with_productName = sorted_orders.map(lambda x: (broadcast_products.value.get(x[0]),x[1]))

# %%
sorted_orders_with_productName.map(lambda x: (x[0][0],x[1])).take(10)
# Out:
# [('Field & Stream Sportsman 16 Gun Fire Safe', 6929653.499999708),
#  ('Perfect Fitness Perfect Rip Deck', 4421143.019999639),
#  ("Diamondback Women's Serene Classic Comfort Bi", 4118425.419999785),
#  ("Nike Men's Free 5.0+ Running Shoe", 3667633.1999997487),
#  ("Nike Men's Dri-FIT Victory Golf Polo", 3147800.0),
#  ('Pelican Sunstream 100 Kayak', 3099844.999999871),
#  ("Nike Men's CJ Elite 2 TD Football Cleat", 2891757.5399998166),
#  ("O'Brien Men's Neoprene Life Vest", 2888993.9399996493),
#  ("Under Armour Girls' Toddler Spine Surge Runni", 1269082.649999932),
#  ('adidas Youth Germany Black/Red Away Match Soc', 67830.0)]

# %%
sortedOrders_category_price = sorted_orders_with_productName.map(lambda x: (x[0][1],x[1]))

# %%
sortedOrders_category_price.take(10)
# Out:
# [(45, 6929653.499999708),
#  (17, 4421143.019999639),
#  (43, 4118425.419999785),
#  (9, 3667633.1999997487),
#  (24, 3147800.0),
#  (48, 3099844.999999871),
#  (18, 2891757.5399998166),
#  (46, 2888993.9399996493),
#  (29, 1269082.649999932),
#  (26, 67830.0)]

# %% [markdown]
# ### [Example]: Most and least profitable Categories

# %%
print("(categoryId, SubTotal)")
sortedOrders_category_price.reduceByKey(lambda x,y: (x+y)).take(10)
# Out:
# (categoryId, SubTotal)
# [(24, 3147800.0),
#  (48, 3113844.599999871),
#  (18, 2891757.5399998166),
#  (46, 2888993.9399996493),
#  (26, 151706.19999999998),
#  (12, 85205.40999999995),
#  (6, 44585.09000000002),
#  (10, 54895.53),
#  (44, 56848.419999999955),
#  (40, 133671.50999999978)]

# %%
sorted_category_subtotal = sortedOrders_category_price.map(lambda x: (broadcast_categories.value.get(x[0]),x[1]))

# %% [markdown]
# #### [Example]: Most profitable 10 categories

# %%
print("(categoryName, Subtotal)")
sorted_category_subtotal.sortBy(lambda x: x[1], ascending = False).take(10)
# Out:
# (categoryName, Subtotal)
# [('Fishing', 6929653.499999708),
#  ('Cleats', 4421143.019999639),
#  ('Camping & Hiking', 4118425.419999785),
#  ('Cardio Equipment', 3667633.1999997487),
#  ("Women's Apparel", 3147800.0),
#  ('Water Sports', 3099844.999999871),
#  ("Men's Footwear", 2891757.5399998166),
#  ('Indoor/Outdoor Games', 2888993.9399996493),
#  ('Shop By Sport', 1269082.649999932),
#  ("Girls' Apparel", 67830.0)]

# %% [markdown]
# #### [Example]: Least profitable 10 categories

# %%
sorted_category_subtotal.sortBy(lambda x: x[1], ascending = True).take(10)
# Out:
# [("Kids' Golf Clubs", 5937.299999999995),
#  ('Fitness Accessories', 5999.899999999999),
#  ("Kids' Golf Clubs", 6599.8899999999985),
#  ("Men's Golf Clubs", 7539.419999999991),
#  ('Soccer', 7999.35999999999),
#  ('Golf Shoes', 8208.0),
#  ('Golf Apparel', 8399.299999999988),
#  ('Basketball', 8399.719999999996),
#  ('Basketball', 8699.709999999995),
#  ('Golf Apparel', 8839.319999999989)]

# %% [markdown]
# ### [Example]: Highest and Lowest SubTotals by Shopping Cart (OrderId)

# %%
def make_orderItems_pairRdd(line):
    orderItems_orderId = int(line.split(",")[1])
    orderItems_subTotal = float(line.split(",")[4])
    
    return (orderItems_orderId, orderItems_subTotal)

# %%
orderItem_SubTotal = order_item_rdd.map(make_orderItems_pairRdd)

# %%
print("(OrderId, SubTotal)")
orderItem_SubTotal.take(10)
# Out:
# (OrderId, SubTotal)
# [(1, 299.98),
#  (2, 199.99),
#  (2, 250.0),
#  (2, 129.99),
#  (4, 49.98),
#  (4, 299.95),
#  (4, 150.0),
#  (4, 199.92),
#  (5, 299.98),
#  (5, 299.95)]

# %% [markdown]
# #### [Example]: Highest 10 SubTotals in shopping cart

# %%
print("(orderId, Total_SubTotal)")
orderItem_SubTotal.reduceByKey(lambda x,y: (x+y))\
.map(lambda x: (x[1],x[0]))\
.sortByKey(False)\
.map(lambda x: (x[1],x[0]))\
.take(10)
# Out:
# (orderId, Total_SubTotal)
# [(68703, 3449.9100000000003),
#  (68724, 2859.8900000000003),
#  (68858, 2839.91),
#  (68809, 2779.86),
#  (68766, 2699.9),
#  (68806, 2629.92),
#  (68821, 2629.92),
#  (68778, 2629.9),
#  (68848, 2399.96),
#  (68875, 2399.95)]

# %% [markdown]
# #### [Example]: Lowest  10 SubTotals in shopping cart

# %%
print("(orderId, Total_SubTotal)")
orderItem_SubTotal.reduceByKey(lambda x,y: (x+y))\
.map(lambda x: (x[1],x[0]))\
.sortByKey(True)\
.map(lambda x: (x[1],x[0]))\
.take(10)
# Out:
# (orderId, Total_SubTotal)
# [(1944, 9.99),
#  (11102, 9.99),
#  (12380, 9.99),
#  (21816, 9.99),
#  (23322, 9.99),
#  (41098, 9.99),
#  (5557, 9.99),
#  (7530, 14.99),
#  (18772, 14.99),
#  (26612, 14.99)]

# %% [markdown]
# ### [Example]: Finding Most and Least profitable customers and cities

# %%
customerId_SubTotal = orderItem_SubTotal.map(lambda x: (broadcast_orders.value.get(x[0]),x[1])).filter(lambda x: x[0] != None)

# %%
print("(customerId, subTotal)")
customerId_SubTotal.take(10)
# Out:
# (customerId, subTotal)
# [(11318, 299.98),
#  (11318, 299.95),
#  (11318, 99.96),
#  (11318, 299.98),
#  (11318, 129.99),
#  (4530, 199.99),
#  (4530, 299.98),
#  (4530, 79.95),
#  (2568, 50.0),
#  (2568, 199.99)]

# %% [markdown]
# #### customerId == 9515 --> orders' subtotals

# %%
print("(customerId = 9515)")
customerId_SubTotal.filter(lambda x: x[0] == 9515).take(100)
# Out:
# (customerId = 9515)
# [(9515, 119.98),
#  (9515, 199.99),
#  (9515, 199.99),
#  (9515, 250.0),
#  (9515, 599.99),
#  (9515, 199.95),
#  (9515, 1999.99),
#  (9515, 399.98)]

# %% [markdown]
# ### Preparing of Customer and Orders Pair RDDs

# %%
customerId_SubTotal.reduceByKey(lambda x,y: (x+y)).take(10)
# Out:
# [(11318, 2489.71),
#  (4530, 1499.7900000000002),
#  (2568, 925.9100000000001),
#  (656, 1875.8000000000002),
#  (4840, 1199.8799999999999),
#  (2636, 1039.79),
#  (1148, 4109.710000000001),
#  (1406, 1601.8500000000001),
#  (8646, 1639.83),
#  (8912, 1819.7800000000002)]

# %%
customerId_Total = customerId_SubTotal.reduceByKey(lambda x,y: (x+y))\
.map(lambda x: (x[1],x[0]))\
.map(lambda x: (x[1],x[0]))

# %% [markdown]
# ### [Example]: Most profitable 10 customers

# %%
print("(customerId, Total)")
customerId_Total.sortBy(lambda x: x[1], ascending=False).take(10)
# Out:
# (customerId, Total)
# [(9337, 6585.330000000002),
#  (3710, 6169.4),
#  (10744, 5799.5),
#  (749, 5759.539999999999),
#  (5411, 5174.56),
#  (8314, 5169.449999999999),
#  (173, 5149.37),
#  (5186, 5113.57),
#  (7802, 4904.450000000001),
#  (8290, 4754.369999999999)]

# %%
profitableCustomerName = customerId_Total.map(lambda x: (broadcast_customers.value.get(x[0]),x[1]))

# %%
print("(CustomerName, TotalAmount)")
profitableCustomerName.map(lambda x: (x[0][0],x[1])).sortBy(lambda x: x[1], ascending=False).take(10)
# Out:
# (CustomerName, TotalAmount)
# [('Mary Smith', 6585.330000000002),
#  ('Ashley Smith', 6169.4),
#  ('Samantha Smith', 5799.5),
#  ('Jesse Matthews', 5759.539999999999),
#  ('Robert Crane', 5174.56),
#  ('Angela Walsh', 5169.449999999999),
#  ('Jose Smith', 5149.37),
#  ('Jason Robinson', 5113.57),
#  ('Mary Acevedo', 4904.450000000001),
#  ('Benjamin Jennings', 4754.369999999999)]

# %% [markdown]
# ### [Example]: Least profitable 10 customers

# %%
print("(CustomerName, TotalAmount)")
profitableCustomerName.map(lambda x: (x[0][0],x[1])).sortBy(lambda x: x[1], ascending = True).take(10)
# Out:
# (CustomerName, TotalAmount)
# [('Mary Jenkins', 14.99),
#  ('Mary Wood', 24.99),
#  ('Frances Smith', 24.99),
#  ('Mary Robinson', 30.0),
#  ('Mary Kim', 30.0),
#  ('Mary Long', 31.98),
#  ('Nathan Morton', 31.99),
#  ('Cynthia Crawford', 31.99),
#  ('Mary Williams', 34.99),
#  ('Mary Meyer', 39.98)]

# %% [markdown]
# ### [Example]: Sales most total amount by Cities

# %%
profitableCustomerName.map(lambda x: (x[0][1],x[1])).reduceByKey(lambda x,y: (x+y)).take(10)
# Out:
# [('Memphis', 37013.700000000004),
#  ('Irving', 12244.79),
#  ('Augusta', 16462.95),
#  ('Brooklyn', 201293.47000000003),
#  ('Orlando', 32547.890000000003),
#  ('Pharr', 16408.399999999998),
#  ('Clearfield', 10603.990000000002),
#  ('Florissant', 18462.910000000003),
#  ('Los Angeles', 223489.27000000005),
#  ('Greeley', 16578.010000000002)]

# %% [markdown]
# ### [Example]: Sales least total amount by Cities

# %%
profitableCustomerName.map(lambda x: (x[0][1],x[1]))\
.reduceByKey(lambda x,y: (x+y))\
.sortBy(lambda x: x[1], ascending = True).take(10)
# Out:
# [('Malden', 299.98),
#  ('Nashville', 799.9),
#  ('Norwalk', 839.87),
#  ('Conway', 959.94),
#  ('Sumner', 1018.88),
#  ('San Pedro', 1179.8),
#  ('Toa Alta', 1297.62),
#  ('Palo Alto', 1349.73),
#  ('Grove City', 1349.96),
#  ('Dubuque', 1448.9)]
